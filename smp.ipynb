# %%
import os
#модуль для работы с ftp
import ftplib
#модуль для работы с zip архивами
from zipfile import *
#Библиотека для работы с Oracle
import cx_Oracle
import pandas as pd
import datetime as dt
import time

# %%
#!!!Важно. Установленная по умолчанию в Canopy версия библиотеки lxml не умеет читать кодировку windows-1251
#Поэтому необходимо скачать с сайта https://pypi.python.org/pypi/lxml последнюю версию (3.7.3) библиотеки 
#Подключаем библиотеку для парсинга XML
import lxml.etree as et

# %%
# Для корректного отображения оракловых сообщений
os.environ['NLS_LANG'] = 'AMERICAN_AMERICA.AL32UTF8'

# %%
gloglist=[]
def log(atext):
    global gloglist
    gloglist.append(time.asctime(time.localtime(time.time()))+' | '+atext+'\n')

# %%
def savelog():
    global gloglist
    logfile=open('z:\\Python\\zakupki\\log.txt','w') #Создаем новый файл в режиме записи
    try:
        logfile.writelines(gloglist)
    finally:
        logfile.close()
    gloglist=[]

# %%
#Процедура скачивает файл filename с указанной директории directory ftp и кладет его по указанному локальному пути 
def download(ftp,directory,loc_filepath,filename):
    ftp.cwd(directory) #Задает текущую директорию на ftp
    loc_file_name=os.path.join(loc_filepath, filename) #конкатенирует имя файла с путем
    #Открывает файл для записи в двоичном формате. Указатель стоит в начале файла. 
    #Создает файл с именем имя_файла, если такового не существует.
    f = open(loc_file_name,"wb")
    #Получить файл в двоичном режиме. Команда должна иметь соответствующую команду RETR: 'RETR имя_файла'.
    ftp.retrbinary("RETR " + filename,f.write)
    f.close()

# %%
#Функция возвращает список файлов или папок в указанной директории на ftp
def get_ftp_dir_list(ftp, ftp_path):
    ftp.cwd(ftp_path) #Задает текущую директорию на ftp
    llist = []
    #Получение файла или каталога в ASCII режиме передачи. 
    #Команда должна иметь соответствующую команду RETR (см. retrbinary ()) или команду такую как LIST, NLST или MLSD
    ftp.retrlines("LIST", llist.append)
    #т.к. в полученном списке присутствуют все атрибуты файла или папки, надо вычленить только имя
    llist=[s.split(None, 8)[-1].lstrip() for s in llist]
    return llist

# %%
def unzipall(path,archname):
    #Проверяем, является ли указанный файл zip архивом
    if is_zipfile(path + archname):
        #Открываем архив на чтение
        z = ZipFile(path + archname, 'r')
        #Распаковываем все файлы из архива по указанному пути
        z.extractall(path)
        #Возвращаем список файлов в архиве
        return z.namelist()
        z.close()
    else:
        print('Некорректный архив : ' +  archname)

# %%
def str_to_date(astrdate):
    #Даты в xml пишутся по разному. 2015-01-16T00:00:00 или 2015-01-16
    if len(astrdate)==0:
        return None
    elif astrdate[0].text[0]=='0':
        return None
    elif ('T' in astrdate[0].text):
        return dt.datetime.strptime(astrdate[0].text, '%Y-%m-%dT%H:%M:%S')
    else:
        return dt.datetime.strptime(astrdate[0].text, '%Y-%m-%d')

# %%
def xpath_nulls(atag_value):
    if len(atag_value)==0:
        return None
    else:
        return atag_value[0].text

# %%
def xpath_float(atag_value):
    if len(atag_value)==0:
        return 0
    else:
        return float(atag_value[0].text)

# %%
#Функция парсинга xml
def parse_xml(afile, adoc):
    #парсим файл XML и создаем дерево елементов element tree
    etxml = et.parse(afile)
    #получаем корневой элемент дерева
    root=etxml.getroot()
    #Данный цикл позволяет получить список всех элементов (тэгов) дерева, названий и значений
    #Это особенно актуально, когда перед элементом указывается пространство имен (name space), например
    #{http://zakupki.gov.ru/223fz/contract/1}contractRegNumber
    #Это нужно при поиске конкретных тэгов с помощью функций xpath и findall
    #for item in root.iterfind('.//'):
    #    print item.tag + '  :  ' + item.text
    #В аргументе функции xpath указываем строку для поиска, здесь './/' означает, 
    #что надо искать не только среди потомков корневого элемента, но во всех элементах дерева вообще
    #также перечисляем все пространства имен, используемые перед названием тэга, их можно взять из заголовка xml
    #они находятся после ключа xmlns= (для тэгов без указания пространства имен, например <inn>5260267654</inn>) 
    #или xmlns: (для тэгов с указанием пространтства имен, например <ns2:code>40000</ns2:code> ), 
    #сами название пространств имен в xpath не обязательно должны совпадать с xml, но пути и URL должны совпадать
    if adoc=='contract':
        acontract=[ 
            root.xpath('.//ns2:contractRegNumber',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/contract/1'})[0].text,
            str_to_date(root.xpath('.//ns2:contractDate',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/contract/1'})),
            float(root.xpath('.//ns2:price',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/contract/1'})[0].text),
            root.xpath('.//ns2:currency/ns:code',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/contract/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})[0].text,
            root.xpath('.//ns2:customer/ns:mainInfo/ns:fullName',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/contract/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})[0].text,
            root.xpath('.//ns2:customer/ns:mainInfo/ns:inn',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/contract/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})[0].text,
            root.xpath('.//ns2:customer/ns:mainInfo/ns:kpp',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/contract/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})[0].text,
            xpath_nulls(root.xpath('.//ns2:subjectContract',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/contract/1'})),
            xpath_nulls(root.xpath('.//ns2:provider',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/contract/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})),
            [s.text for s in root.xpath('.//ns2:contractPositions/ns2:contractPosition/ns2:okpd2/ns:code',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/contract/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})],
            [s.text for s in root.xpath('.//ns2:contractPositions/ns2:contractPosition/ns2:okpd/ns:code',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/contract/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})],
            [s.text for s in root.xpath('.//ns2:contractPositions/ns2:contractPosition/ns2:okdp/ns:code',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/contract/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})],
            xpath_nulls(root.xpath('.//ns2:endExecutionTerm',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/contract/1'})),
            xpath_nulls(root.xpath('.//ns2:purchaseNoticeInfo/ns2:purchaseNoticeNumber',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/contract/1'})),
            xpath_nulls(root.xpath('.//ns2:contractConfirmingDocs/ns2:contractDoc/ns2:docNum',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/contract/1'}))
            ]
    elif adoc=='pcontract':
        acontract=[
            xpath_nulls(root.xpath('.//ns2:registrationNumber',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/purchase/1'})),
            str_to_date(root.xpath('.//ns2:contractCreateDate',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/purchase/1'})),
            xpath_float(root.xpath('.//ns2:sum',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/purchase/1'})),
            xpath_nulls(root.xpath('.//ns2:currency/ns:code',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/purchase/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})),
            xpath_nulls(root.xpath('.//ns2:customerInfo/ns:fullName',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/purchase/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})),
            xpath_nulls(root.xpath('.//ns2:customerInfo/ns:inn',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/purchase/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})),
            xpath_nulls(root.xpath('.//ns2:customerInfo/ns:kpp',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/purchase/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})),
            xpath_nulls(root.xpath('.//ns2:purchaseInfo/ns:name',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/purchase/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})),
            [s.text for s in root.xpath('.//ns2:contractItems/ns2:contractItem/ns:okved/ns:name',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/purchase/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})
                            +root.xpath('.//ns2:contractItems/ns2:contractItem/ns:okved2/ns:name',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/purchase/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})
                            +root.xpath('.//ns2:contractItems/ns2:contractItem/ns:okdp/ns:name',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/purchase/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})
                            +root.xpath('.//ns2:contractItems/ns2:contractItem/ns:okdp2/ns:name',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/purchase/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})
            ],
            xpath_nulls(root.xpath('.//ns2:fulfillmentDate',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/purchase/1'})),
            xpath_nulls(root.xpath('.//ns2:purchaseInfo/ns:purchaseNoticeNumber',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/purchase/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'})),
            xpath_nulls(root.xpath('.//ns2:purchaseInfo/ns:nothing',namespaces={'ns2' : 'http://zakupki.gov.ru/223fz/purchase/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'}))
            ]
    #Альтернативная xpath функция, но с меньшими возможностями и немного отличным синтаксисом поискового запроса
    #lm = root.findall('.//{http://zakupki.gov.ru/223fz/contract/1}contractRegNumber')
    return acontract

# %%
def compdate(afname,adfrom,adto):
    ifrom=afname.find('_000000_')
    if ifrom==-1:
        return False
    else:
        ldfile=afname[ifrom+8:ifrom+16]
        return dt.datetime.strptime(adfrom, '%Y%m%d')\
               <=dt.datetime.strptime(ldfile, '%Y%m%d')\
               <=dt.datetime.strptime(adto, '%Y%m%d')

# %%
def complists(alist1, alist2):
    for i in alist1:
        for j in alist2:
            si=unicode(i)+'.'
            sj=unicode(j)+'.'
            if si.find(sj)==0:
                return True
    return False

# %%
#Загружаем все файлы с ftp госзакупок из подпапки ftp_dir  в локальную папку lxmlpath
#def gz_get_ftp_files(ftp, ftp_dir, lxmlpath, adf_orgs, adoc, adfrom, adto, aregions=None):
def gz_get_ftp_files(ftp, ftp_dir, lxmlpath, okved2, adoc, adfrom, adto, aregions=None):
    #создаем DataFrame для данных контрактов
    contracts=pd.DataFrame(columns=['number','date','price','currency','fullname','inn',
                                    'kpp','subject','issmp','okpd2','okpd','okdp','end','noticenum','ndoc',
                                    'zip','xml','region'])
    for s in get_ftp_dir_list(ftp,"/out/published/"):
        i=0
        #s=get_ftp_dir_list(ftp, "/out/published/")[0]
        if (aregions!=None) and (s in aregions):
            try:
                lpath="/out/published/" + s + ftp_dir
                time.asctime(time.localtime(time.time()))
                print(time.asctime(time.localtime(time.time())) + ' | Каталог: ' + s)
                ftp.cwd(lpath)
                lftplist=get_ftp_dir_list(ftp, lpath)
                print('Всего файлов (архивов) в FTP каталоге: ' +str(len(lftplist)))
                for f in lftplist:
                    if (f[-4:]=='.zip') and compdate(f,adfrom,adto):
                        log(f)
                        download(ftp, lpath,lxmlpath,f)
                        i+=1
                        archlist=unzipall(lxmlpath,f)
                        #Поскольку в разных архивах содержатся XML файлы с одинаковыми названиями 
                        #- добавляем к названию файла уникальный для архива номер, либо после парсинга сразу удаляем файл XML
                        for x in archlist:
                            #если файл не нулевой длины - парсим xml и загружаем данные в DataFrame
                            if os.path.getsize(lxmlpath + x)!= 0:
                                log(x)
                                contract=parse_xml(lxmlpath + x, adoc)
                                # Удаляем дубли в списке оквэд
                                contract[9]=list(set(contract[9]))
                                if complists(contract[9], okved2):
                                    #добавляем имена файлов zip и xml в список
                                    contract.append(f)
                                    contract.append(x)
                                    contract.append(s)
                                    #Могут досылать исправленные данные по контракту в разные дни. Это надо обрабатывать.
                                    #!!!Данный функционал работает не стабильно!!!
                                    #Если мы присваиваем один DataFrame другому или один List другому с помощью оператора =, 
                                    #то в этом случае объект остается один и тот же. Копируется только ссылка на него
                                    #Функция copy() и list() позволяет скопировать физически сам объект и избежать сообщения:
                                    #A value is trying to be set on a copy of a slice from a DataFrame
                                    #tmpdf=contracts[(contracts['number']==contract[0])&(contracts['date']==contract[1])].copy()
                                    #if len(tmpdf.index)!=0:
                                    #    tmpdf.loc[0]=list(contract)
                                    #    contracts.loc[contracts[(contracts['number']==contract[0])&(contracts['date']==contract[1])].index,tmpdf.columns]=tmpdf.copy()
                                    #    print str(contracts[(contracts['number']==contract[0])&(contracts['date']==contract[1])].index)+' upd '.join(list(map(unicode,contract)))
                                    #else:
                                    contracts.loc[len(contracts)]=contract
                                    #    print ' add '.join(list(map(unicode,contract)))
                                #os.rename(lxmlpath + x,lxmlpath + x[:-4] + '_' + str(i) + x[-4:])
                            os.remove(lxmlpath + x)    
                        #удаляем файл архива    
                        os.remove(lxmlpath + f)
                        if i%100==0:
                            print(time.asctime(time.localtime(time.time())) 
                            + ' | Обработано '+str(i)+' файлов из '+str(len(lftplist)) 
                            +' ('+str(int(round(float(i)/len(lftplist)*100)))+'%)')
            except ftplib.error_perm:
                print('В папке ' + s + ' каталог ' + ftp_dir + ' не существует!')
    #Могут досылать исправленные данные по контракту в разные дни. Это надо обрабатывать.
    contracts=contracts.drop_duplicates(['number','date'],keep='last')
    contracts.index=range(len(contracts.index))
    print(u'Окончание обработки: '+time.asctime(time.localtime(time.time())))
    savelog()
    return contracts

# %%
#Блок подготовки и проверки SQL команды
def insert_prepare(asql,acursor):
    try:
        acursor.prepare(asql)
    except cx_Oracle.DatabaseError as exception:
        print('Failed to prepare cursor')
        print(exception)
        exit(1)

# %%
def load_from_ora(asql):    
    conn=cx_Oracle.connect('analytics/analytics@fst_rac')
    cursor=conn.cursor()
    try:
        insert_prepare(asql,cursor)
        try:
            cursor.execute(cursor.statement)
            ltable=cursor.fetchall()
            #получаем названия полей запроса
            lcols=[col_desc[0] for col_desc in cursor.description]
        except cx_Oracle.DatabaseError as exception:
            print('Failed to insert row')
            print(exception)
            print(cursor.statement)
            exit(1)
        df=pd.DataFrame(ltable, columns=lcols)
        return df
    finally:
        cursor.close()
        conn.close()

# %%
def load_df_to_ora(adf):
    conn=cx_Oracle.connect('analytics/analytics@fst_rac')
    cursor=conn.cursor()
    try:
        isql = """
                  INSERT INTO ZAKUPKI_SMP 
                  (NNUMBER,NDATE,PRICE,CURRENCY,FULLNAME,INN,KPP,SUBJECT,ISSMP,NEND,NOTICENUM,NDOC,ZIP,NXML,NREGION) 
                  VALUES (:S_NNUMBER,:S_NDATE,:S_PRICE,:S_CURRENCY,:S_FULLNAME,:S_INN,:S_KPP,:S_SUBJECT,:S_ISSMP,:S_NEND,:S_NOTICENUM,:S_NDOC,:S_ZIP,:S_NXML,:S_REGION)
               """
        isql2 = """
                  INSERT INTO ZAKUPKI_OKPD2 
                  (NNUMBER,OKPD2,NDATE,NOTICENUM) 
                  VALUES (:S_NNUMBER,:S_OKPD2,:S_NDATE,:S_NOTICENUM)
               """
        usql = """
                  UPDATE OIL_PURCH_TR_EIS 
                  SET PRICE=:S_PRICE,
                      CURRENCY=:S_CURRENCY,
                      FULLNAME=:S_FULLNAME,
                      INN=:S_INN,
                      KPP=:S_KPP,
                      SUBJECT=:S_SUBJECT,
                      POSITION=:S_POSITION,
                      NEND=:S_NEND,
                      ZIP=:S_ZIP,
                      NXML=:S_NXML
                  WHERE
                      NNUMBER=:S_NNUMBER AND
                      NDATE=:S_NDATE AND 
                      INN=:S_INN AND 
                      KPP=:S_KPP AND 
                      NOTICENUM=:S_NOTICENUM AND 
                      NDOC=:S_NDOC
               """
        #Блок подготовки и проверки SQL команды
        for i in range(len(adf.index)):
            #if adf['NOTICENUM'][i]=='NULL':
            insert_prepare(isql,cursor)
            #else:
            #    insert_prepare(usql,cursor)
            try:
                #Выполнение Insert
                cursor.execute (cursor.statement,S_NNUMBER=adf['number'][i],
                                S_NDATE=adf['date'][i],S_PRICE=adf['price'][i],
                                S_CURRENCY=adf['currency'][i],S_FULLNAME=adf['fullname'][i],
                                S_INN=adf['inn'][i],S_KPP=adf['kpp'][i],S_SUBJECT=adf['subject'][i],
                                S_ISSMP=adf['issmp'][i],S_NEND=adf['end'][i],
                                S_NOTICENUM=adf['noticenum'][i],S_NDOC=adf['ndoc'][i],
                                S_ZIP=adf['zip'][i],S_NXML=adf['xml'][i], S_REGION=adf['region'][i]
                                )
            except cx_Oracle.DatabaseError as exception:
                print('Failed to insert row')
                print(exception)
                print(cursor.statement)
                #print str(df['NYEAR'][i])+'|'+str(df['GROUP_NUMBER'][i])+'|'+str(df['GROUP_NAME'][i])+'|'+str(df['ORG_REG_NUMBER'][i])+'|'+str(df['ORG_NAME'][i])
                exit(1)
            for lcode in adf['okpd2'][i]:
                #if adf['NOTICENUM'][i]=='NULL':
                insert_prepare(isql2,cursor)
                #else:
                #    insert_prepare(usql,cursor)
                try:
                    #Выполнение Insert
                    cursor.execute (cursor.statement,S_NNUMBER=adf['number'][i],
                                S_OKPD2=lcode, S_NDATE=adf['date'][i],
                                S_NOTICENUM=adf['noticenum'][i]
                                )
                except cx_Oracle.DatabaseError as exception:
                    print('Failed to insert row')
                    print(exception)
                    print(cursor.statement)
                    #print str(df['NYEAR'][i])+'|'+str(df['GROUP_NUMBER'][i])+'|'+str(df['GROUP_NAME'][i])+'|'+str(df['ORG_REG_NUMBER'][i])+'|'+str(df['ORG_NAME'][i])
                    exit(1)
            if (i>0) and (i%100==0):
                print(u' Обработано строк: '+str(i))
        conn.commit()   
    finally:
        cursor.close()
        conn.close()

# %%
sql=u"""
    select *
    from analytics.okved2
    """      
df_okved=load_from_ora(sql)

# %%
#создаем объект ftp для заданного адреса ftp-сервера
ftp = ftplib.FTP("ftp.zakupki.gov.ru")

# %%
#коннектимся к серверу с именем пользователя и паролем
ftp.login("fz223free", "fz223free")
# Out:
# '230 Login successful.'

# %%
contracts=gz_get_ftp_files(ftp, "/contract/daily/", "z:\\Python\\zakupki\\contracts_xml\\",df_okved.OKVED_NAME.tolist(),
                          'contract','20180101','20180831',
                         ['Moskovskaya_obl','Krasnoyarskii_krai','Tatarstan_Resp','Primorskii_krai',
                          'Kaliningradskaya_obl','Chukotskii_AO'])
# Out:
# Wed Sep 12 09:03:41 2018 | Каталог: Chukotskii_AO
# Всего файлов (архивов) в FTP каталоге: 951
# Wed Sep 12 09:03:55 2018 | Обработано 100 файлов из 951 (11%)
# Wed Sep 12 09:04:02 2018 | Каталог: Kaliningradskaya_obl
# Всего файлов (архивов) в FTP каталоге: 1970
# Wed Sep 12 09:04:27 2018 | Обработано 100 файлов из 1970 (5%)
# Wed Sep 12 09:04:56 2018 | Обработано 200 файлов из 1970 (10%)
# Wed Sep 12 09:05:22 2018 | Обработано 300 файлов из 1970 (15%)
# Wed Sep 12 09:06:00 2018 | Обработано 400 файлов из 1970 (20%)
# Wed Sep 12 09:06:16 2018 | Каталог: Krasnoyarskii_krai
# Всего файлов (архивов) в FTP каталоге: 1987
# Wed Sep 12 09:07:42 2018 | Обработано 100 файлов из 1987 (5%)
# Wed Sep 12 09:09:48 2018 | Обработано 200 файлов из 1987 (10%)
# Wed Sep 12 09:11:48 2018 | Обработано 300 файлов из 1987 (15%)
# Wed Sep 12 09:14:10 2018 | Обработано 400 файлов из 1987 (20%)
# Wed Sep 12 09:15:30 2018 | Каталог: Moskovskaya_obl
# Всего файлов (архивов) в FTP каталоге: 2158
# Wed Sep 12 09:21:43 2018 | Обработано 100 файлов из 2158 (5%)
# Wed Sep 12 09:29:48 2018 | Обработано 200 файлов из 2158 (9%)
# Wed Sep 12 09:36:01 2018 | Обработано 300 файлов из 2158 (14%)
# Wed Sep 12 09:41:08 2018 | Обработано 400 файлов из 2158 (19%)
# 53041  166001001  Ремонт очистных устройств, устройств контроля ...  false
# 53042  166101001           1616-2018-00670 Поставка листов стальных   true
# 53043  165501001  Поставка двух тракторов Беларус-1221.2 в компл...  false
# 53044  165701001  (ЕЭС) Строительство системы интеллектуального ...   true
# 53045  165901001  поставка хлеба и хлебобулочных изделий в ДОУ Т...  false
# 53046  165501001  Поставка автотопливозаправщика мод. 56142-0000...  false
# 53047  166001001  Техническое обслуживание и ремонт автомобиля А...  false
# 53048  166001001  Выполнение работ по оформлению земельных участ...  false
# 53049  165901001  Поставка оборудования для оснащения новых учеб...  false
# 53050  165501001  Поставка электрических приборов, способствующи...  false
# 53051  165901001  поставка хлеба и хлебобулочных изделий в ДОУ Л...  false
# 53052  165901001  поставка хлеба и хлебобулочных изделий в ДОУ В...  false
# 53053  166001001  Установка и привязка реперов, маркерных пункто...  false
#
#                                                    okpd2 okpd okdp  \
# 0                                         [33.12.29.000]   []   []
# 1                                                 [71.2]   []   []
# 2                                         [05.10.10.136]   []   []
# 3                                                   [45]   []   []
# 4                                         [47.30.10.000]   []   []
# 5                                                 [63.1]   []   []
# 6                                                 [46.3]   []   []
# 7                                                 [25.9]   []   []
# 8      [29.32.30.390, 22.11.13.110, 17.22.11.110, 20....   []   []
# 9                                         [64.19.21.000]   []   []
# 10                                             [47.30.2]   []   []
# 11                                               [33.12]   []   []
# 12                                               [33.12]   []   []
# 13                                             [33.12.1]   []   []
# 14                                                [46.3]   []   []
# 15                                        [71.20.13.110]   []   []
# 16                                        [42.21.22.120]   []   []
# 17                                               [33.12]   []   []
# 18                                        [20.11.11.130]   []   []
# 19                                        [17.12.14.142]   []   []
# 20                                        [17.12.14.142]   []   []
# 21                                        [45.11.11.000]   []   []
# 22                                             [28.29.4]   []   []
# 23                                             [26.20.1]   []   []
# 24                                            [28.15.10]   []   []
# 25                                             [31.01.1]   []   []
# 26                                        [25.61.11.111]   []   []
# 27                                               [33.12]   []   []
# 28                                        [71.12.40.110]   []   []
# 29                                            [28.15.10]   []   []
# ...                                                  ...  ...  ...
# 53024                                     [25.30.11.130]   []   []
# 53025                                         [22.29.25]   []   []
# 53026                                          [10.32.1]   []   []
# 53027                                         [10.11.31]   []   []
# 53028                                     [24.42.22.111]   []   []
# 53029                                         [10.11.31]   []   []
# 53030                                     [71.20.13.110]   []   []
# 53031                                     [17.23.13.110]   []   []
# 53032                                     [25.30.11.130]   []   []
# 53033                                     [25.30.11.130]   []   []
# 53034                                         [71.12.11]   []   []
# 53035                                     [25.30.11.130]   []   []
# 53036                                            [27.32]   []   []
# 53037                                     [25.30.11.130]   []   []
# 53038                                     [24.10.11.110]   []   []
# 53039                                     [41.20.40.900]   []   []
# 53040                                     [10.71.11.110]   []   []
# 53041                                            [33.12]   []   []
# 53042                                     [24.10.11.110]   []   []
# 53043                                     [28.92.30.190]   []   []
# 53044                                         [41.20.40]   []   []
# 53045                                     [10.71.11.110]   []   []
# 53046                                     [29.10.41.113]   []   []
# 53047                                          [45.20.1]   []   []
contract_Tatarstan_Resp_20180831_000000_201808...  Tatarstan_Resp
# 53044  contract_Tatarstan_Resp_20180831_000000_201808...  Tatarstan_Resp
# 53045  contract_Tatarstan_Resp_20180831_000000_201808...  Tatarstan_Resp
# 53046  contract_Tatarstan_Resp_20180831_000000_201808...  Tatarstan_Resp
# 53047  contract_Tatarstan_Resp_20180831_000000_201808...  Tatarstan_Resp
# 53048  contract_Tatarstan_Resp_20180831_000000_201808...  Tatarstan_Resp
# 53049  contract_Tatarstan_Resp_20180831_000000_201808...  Tatarstan_Resp
# 53050  contract_Tatarstan_Resp_20180831_000000_201808...  Tatarstan_Resp
# 53051  contract_Tatarstan_Resp_20180831_000000_201808...  Tatarstan_Resp
# 53052  contract_Tatarstan_Resp_20180831_000000_201808...  Tatarstan_Resp
# 53053  contract_Tatarstan_Resp_20180831_000000_201808...  Tatarstan_Resp
#
# [53054 rows x 18 columns]

# %% [markdown]
# ### Создать таблицу
# -- Create table
# create table ZAKUPKI_SMP
# (
#   nnumber   VARCHAR2(100),
#   ndate     DATE,
#   price     NUMBER(16,2),
#   currency  VARCHAR2(3),
#   fullname  VARCHAR2(1000),
#   inn       VARCHAR2(12),
#   kpp       VARCHAR2(10),
#   subject   VARCHAR2(2000),
#   issmp     VARCHAR2(5),
#   position  VARCHAR2(2000),
#   nend      VARCHAR2(2000),
#   noticenum VARCHAR2(100),
#   ndoc      VARCHAR2(2000),
#   zip       VARCHAR2(255),
#   nxml      VARCHAR2(255),
#   nregion   VARCHAR2(255)
# )
# tablespace USERS
#   pctfree 10
#   initrans 1
#   maxtrans 255
#   storage
#   (
#     initial 64K
#     next 1M
#     minextents 1
#     maxextents unlimited
#   );
#
# #####  Таблица с кодами
# create table ZAKUPKI_OKPD2
# (
#   nnumber   VARCHAR2(100),
#   okpd2     VARCHAR2(255),
#   ndate     DATE,
#   noticenum VARCHAR2(100)
# )
# tablespace USERS
#   pctfree 10
#   initrans 1
#   maxtrans 255
#   storage
#   (
#     initial 64K
#     next 1M
#     minextents 1
#     maxextents unlimited
#   );

# %%
contracts['okpd2']=contracts['okpd2'].apply('; '.join)
contracts['okpd']=contracts['okpd'].apply('; '.join)
contracts['okdp']=contracts['okdp'].apply('; '.join)

# %%
load_df_to_ora(contracts)
# Out:
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
#  Обработано строк: 1300
#  Обработано строк: 1400
#  Обработано строк: 1500
#  Обработано строк: 1600
#  Обработано строк: 1700
#  Обработано строк: 1800
#  Обработано строк: 1900
#  Обработано строк: 2000
#  Обработано строк: 2100
#  Обработано строк: 2200
#  Обработано строк: 2300
#  Обработано строк: 2400
#  Обработано строк: 2500
#  Обработано строк: 2600
#  Обработано строк: 2700
#  Обработано строк: 2800
#  Обработано строк: 2900
#  Обработано строк: 3000
#  Обработано строк: 3100
#  Обработано строк: 3200
#  Обработано строк: 3300
#  Обработано строк: 3400
#  Обработано строк: 3500
#  Обработано строк: 3600
#  Обработано строк: 3700
#  Обработано строк: 3800
#  Обработано строк: 3900
#  Обработано строк: 4000
#  Обработано строк: 4100
#  Обработано строк: 4200
#  Обработано строк: 4300
#  Обработано строк: 4400
#  Обработано строк: 4500
#  Обработано строк: 4600
#  Обработано строк: 4700
#  Обработано строк: 4800
#  Обработано строк: 4900
#  Обработано строк: 5000
#  Обработано строк: 5100
#  Обработано строк: 5200
#  Обработано строк: 5300
#  Обработано строк: 5400
#  Обработано строк: 5500
#  Обработано строк: 5600
#  Обработано строк: 5700
#  Обработано строк: 5800
#  Обработано строк: 5900
#  Обработано строк: 6000
#  Обработано строк: 6100
#  Обработано строк: 6200
#  Обработано строк: 6300
#  Обработано строк: 6400
#  Обработано строк: 6500
#  Обработано строк: 6600
#  Обработано строк: 6700
#  Обработано строк: 6800
#  Обработано строк: 6900
#  Обработано строк: 7000
#  Обработано строк: 7100
#  Обработано строк: 7200
#  Обработано строк: 7300
#  Обработано строк: 7400
#  Обработано строк: 7500
#  Обработано строк: 7600
#  Обработано строк: 7700
#  Обработано строк: 7800
#  Обработано строк: 7900
#  Обработано строк: 8000
#  Обработано строк: 8100
#  Обработано строк: 8200
#  Обработано строк: 8300
#  Обработано строк: 8400
#  Обработано строк: 8500
#  Обработано строк: 8600
#  Обработано строк: 8700
#  Обработано строк: 8800
#  Обработано строк: 8900
#  Обработано строк: 9000
#  Обработано строк: 9100
#  Обработано строк: 9200
#  Обработано строк: 9300
#  Обработано строк: 9400
#  Обработано строк: 9500
#  Обработано строк: 9600
#  Обработано строк: 9700
#  Обработано строк: 9800
#  Обработано строк: 9900
#  Обработано строк: 10000
#  Обработано строк: 10100
#  Обработано строк: 10200
#  Обработано строк: 10300
#  Обработано строк: 10400
#  Обработано строк: 10500
#  Обработано строк: 10600
#  Обработано строк: 10700
#  Обработано строк: 10800
#  Обработано строк: 10900
#  Обработано строк: 11000
#  Обработано строк: 11100
#  Обработано строк: 11200
#  Обработано строк: 11300
#  Обработано строк: 11400
#  Обработано строк: 11500
#  Обработано строк: 11600
#  Обработано строк: 11700
#  Обработано строк: 11800
#  Обработано строк: 11900
#  Обработано строк: 12000
#  Обработано строк: 12100
#  Обработано строк: 12200
#  Обработано строк: 12300
#  Обработано строк: 12400
#  Обработано строк: 12500
#  Обработано строк: 12600
#  Обработано строк: 12700
#  Обработано строк: 12800
#  Обработано строк: 12900
#  Обработано строк: 13000
#  Обработано строк: 13100
#  Обработано строк: 13200
#  Обработано строк: 13300
#  Обработано строк: 13400
#  Обработано строк: 13500
#  Обработано строк: 13600
#  Обработано строк: 13700
#  Обработано строк: 13800
#  Обработано строк: 13900
#  Обработано строк: 14000
#  Обработано строк: 14100
#  Обработано строк: 14200
#  Обработано строк: 14300
#  Обработано строк: 14400
#  Обработано строк: 14500
#  Обработано строк: 14600
#  Обработано строк: 14700
#  Обработано строк: 14800
#  Обработано строк: 14900
#  Обработано строк: 15000
#  Обработано строк: 15100
#  Обработано строк: 15200
#  Обработано строк: 15300
#  Обработано строк: 15400
#  Обработано строк: 15500
#  Обработано строк: 15600
#  Обработано строк: 15700
#  Обработано строк: 15800
#  Обработано строк: 15900
#  Обработано строк: 16000
#  Обработано строк: 16100
#  Обработано строк: 16200
#  Обработано строк: 16300
#  Обработано строк: 16400
#  Обработано строк: 16500
#  Обработано строк: 16600
#  Обработано строк: 16700
#  Обработано строк: 16800
#  Обработано строк: 16900
#  Обработано строк: 17000
#  Обработано строк: 17100
#  Обработано строк: 17200
#  Обработано строк: 17300
#  Обработано строк: 17400
#  Обработано строк: 17500
#  Обработано строк: 17600
#  Обработано строк: 17700
#  Обработано строк: 17800
#  Обработано строк: 17900
#  Обработано строк: 18000
#  Обработано строк: 18100
#  Обработано строк: 18200
#  Обработано строк: 18300
#  Обработано строк: 18400
#  Обработано строк: 18500
#  Обработано строк: 18600
#  Обработано строк: 18700
#  Обработано строк: 18800
#  Обработано строк: 18900
#  Обработано строк: 19000
#  Обработано строк: 19100
#  Обработано строк: 19200
#  Обработано строк: 19300
#  Обработано строк: 19400
#  Обработано строк: 19500
#  Обработано строк: 19600
#  Обработано строк: 19700
#  Обработано строк: 19800
#  Обработано строк: 19900
#  Обработано строк: 20000
#  Обработано строк: 20100
#  Обработано строк: 20200
#  Обработано строк: 20300
#  Обработано строк: 20400
#  Обработано строк: 20500
#  Обработано строк: 20600
#  Обработано строк: 20700
#  Обработано строк: 20800
#  Обработано строк: 20900
#  Обработано строк: 21000
#  Обработано строк: 21100
#  Обработано строк: 21200
#  Обработано строк: 21300
#  Обработано строк: 21400
#  Обработано строк: 21500
#  Обработано строк: 21600
#  Обработано строк: 21700
#  Обработано строк: 21800
#  Обработано строк: 21900
#  Обработано строк: 22000
#  Обработано строк: 22100
#  Обработано строк: 22200
#  Обработано строк: 22300
#  Обработано строк: 22400
#  Обработано строк: 22500
#  Обработано строк: 22600
#  Обработано строк: 22700
#  Обработано строк: 22800
#  Обработано строк: 22900
#  Обработано строк: 23000
#  Обработано строк: 23100
#  Обработано строк: 23200
#  Обработано строк: 23300
#  Обработано строк: 23400
#  Обработано строк: 23500
#  Обработано строк: 23600
#  Обработано строк: 23700
#  Обработано строк: 23800
#  Обработано строк: 23900
#  Обработано строк: 24000
#  Обработано строк: 24100
#  Обработано строк: 24200
#  Обработано строк: 24300
#  Обработано строк: 24400
#  Обработано строк: 24500
#  Обработано строк: 24600
#  Обработано строк: 24700
#  Обработано строк: 24800
#  Обработано строк: 24900
#  Обработано строк: 25000
#  Обработано строк: 25100
#  Обработано строк: 25200
#  Обработано строк: 25300
#  Обработано строк: 25400
#  Обработано строк: 25500
#  Обработано строк: 25600
#  Обработано строк: 25700
#  Обработано строк: 25800
#  Обработано строк: 25900
#  Обработано строк: 26000
#  Обработано строк: 26100
#  Обработано строк: 26200
#  Обработано строк: 26300
#  Обработано строк: 26400
#  Обработано строк: 26500
#  Обработано строк: 26600
#  Обработано строк: 26700
#  Обработано строк: 26800
#  Обработано строк: 26900
#  Обработано строк: 27000
#  Обработано строк: 27100
#  Обработано строк: 27200
#  Обработано строк: 27300
#  Обработано строк: 27400
#  Обработано строк: 27500
#  Обработано строк: 27600
#  Обработано строк: 27700
#  Обработано строк: 27800
#  Обработано строк: 27900
#  Обработано строк: 28000
#  Обработано строк: 28100
#  Обработано строк: 28200
#  Обработано строк: 28300
#  Обработано строк: 28400
#  Обработано строк: 28500
#  Обработано строк: 28600
#  Обработано строк: 28700
#  Обработано строк: 28800
#  Обработано строк: 28900
#  Обработано строк: 29000
#  Обработано строк: 29100
#  Обработано строк: 29200
#  Обработано строк: 29300
#  Обработано строк: 29400
#  Обработано строк: 29500
#  Обработано строк: 29600
#  Обработано строк: 29700
#  Обработано строк: 29800
#  Обработано строк: 29900
#  Обработано строк: 30000
#  Обработано строк: 30100
#  Обработано строк: 30200
#  Обработано строк: 30300
#  Обработано строк: 30400
#  Обработано строк: 30500
#  Обработано строк: 30600
#  Обработано строк: 30700
#  Обработано строк: 30800
#  Обработано строк: 30900
#  Обработано строк: 31000
#  Обработано строк: 31100
#  Обработано строк: 31200
#  Обработано строк: 31300
#  Обработано строк: 31400
#  Обработано строк: 31500
#  Обработано строк: 31600
#  Обработано строк: 31700
#  Обработано строк: 31800
#  Обработано строк: 31900
#  Обработано строк: 32000
#  Обработано строк: 32100
#  Обработано строк: 32200
#  Обработано строк: 32300
#  Обработано строк: 32400
#  Обработано строк: 32500
#  Обработано строк: 32600
#  Обработано строк: 32700
#  Обработано строк: 32800
#  Обработано строк: 32900
#  Обработано строк: 33000
#  Обработано строк: 33100
#  Обработано строк: 33200
#  Обработано строк: 33300
#  Обработано строк: 33400
#  Обработано строк: 33500
#  Обработано строк: 33600
#  Обработано строк: 33700
#  Обработано строк: 33800
#  Обработано строк: 33900
#  Обработано строк: 34000
#  Обработано строк: 34100
#  Обработано строк: 34200
#  Обработано строк: 34300
#  Обработано строк: 34400
#  Обработано строк: 34500
#  Обработано строк: 34600
#  Обработано строк: 34700
#  Обработано строк: 34800
#  Обработано строк: 34900
#  Обработано строк: 35000
#  Обработано строк: 35100
#  Обработано строк: 35200
#  Обработано строк: 35300
#  Обработано строк: 35400
#  Обработано строк: 35500
#  Обработано строк: 35600
#  Обработано строк: 35700
#  Обработано строк: 35800
#  Обработано строк: 35900
#  Обработано строк: 36000
#  Обработано строк: 36100
#  Обработано строк: 36200
#  Обработано строк: 36300
#  Обработано строк: 36400
#  Обработано строк: 36500
#  Обработано строк: 36600
#  Обработано строк: 36700
#  Обработано строк: 36800
#  Обработано строк: 36900
#  Обработано строк: 37000
#  Обработано строк: 37100
#  Обработано строк: 37200
#  Обработано строк: 37300
#  Обработано строк: 37400
#  Обработано строк: 37500
#  Обработано строк: 37600
#  Обработано строк: 37700
#  Обработано строк: 37800
#  Обработано строк: 37900
#  Обработано строк: 38000
#  Обработано строк: 38100
#  Обработано строк: 38200
#  Обработано строк: 38300
#  Обработано строк: 38400
#  Обработано строк: 38500
#  Обработано строк: 38600
#  Обработано строк: 38700
#  Обработано строк: 38800
#  Обработано строк: 38900
#  Обработано строк: 39000
#  Обработано строк: 39100
#  Обработано строк: 39200
#  Обработано строк: 39300
#  Обработано строк: 39400
#  Обработано строк: 39500
#  Обработано строк: 39600
#  Обработано строк: 39700
#  Обработано строк: 39800
#  Обработано строк: 39900
#  Обработано строк: 40000
#  Обработано строк: 40100
#  Обработано строк: 40200
#  Обработано строк: 40300
#  Обработано строк: 40400
#  Обработано строк: 40500
#  Обработано строк: 40600
#  Обработано строк: 40700
#  Обработано строк: 40800
#  Обработано строк: 40900
#  Обработано строк: 41000
#  Обработано строк: 41100
#  Обработано строк: 41200
#  Обработано строк: 41300
#  Обработано строк: 41400
#  Обработано строк: 41500
#  Обработано строк: 41600
#  Обработано строк: 41700
#  Обработано строк: 41800
#  Обработано строк: 41900
#  Обработано строк: 42000
#  Обработано строк: 42100
#  Обработано строк: 42200
#  Обработано строк: 42300
#  Обработано строк: 42400
#  Обработано строк: 42500
#  Обработано строк: 42600
#  Обработано строк: 42700
#  Обработано строк: 42800
#  Обработано строк: 42900
#  Обработано строк: 43000
#  Обработано строк: 43100
#  Обработано строк: 43200
#  Обработано строк: 43300
#  Обработано строк: 43400
#  Обработано строк: 43500
#  Обработано строк: 43600
#  Обработано строк: 43700
#  Обработано строк: 43800
#  Обработано строк: 43900
#  Обработано строк: 44000
#  Обработано строк: 44100
#  Обработано строк: 44200
#  Обработано строк: 44300
#  Обработано строк: 44400
#  Обработано строк: 44500
#  Обработано строк: 44600
#  Обработано строк: 44700
#  Обработано строк: 44800
#  Обработано строк: 44900
#  Обработано строк: 45000
#  Обработано строк: 45100
#  Обработано строк: 45200
#  Обработано строк: 45300
#  Обработано строк: 45400
#  Обработано строк: 45500
#  Обработано строк: 45600
#  Обработано строк: 45700
#  Обработано строк: 45800
#  Обработано строк: 45900
#  Обработано строк: 46000
#  Обработано строк: 46100
#  Обработано строк: 46200
#  Обработано строк: 46300
#  Обработано строк: 46400
#  Обработано строк: 46500
#  Обработано строк: 46600
#  Обработано строк: 46700
#  Обработано строк: 46800
#  Обработано строк: 46900
#  Обработано строк: 47000
#  Обработано строк: 47100
#  Обработано строк: 47200
#  Обработано строк: 47300
#  Обработано строк: 47400
#  Обработано строк: 47500
#  Обработано строк: 47600
#  Обработано строк: 47700
#  Обработано строк: 47800
#  Обработано строк: 47900
#  Обработано строк: 48000
#  Обработано строк: 48100
#  Обработано строк: 48200
#  Обработано строк: 48300
#  Обработано строк: 48400
#  Обработано строк: 48500
#  Обработано строк: 48600
#  Обработано строк: 48700
#  Обработано строк: 48800
#  Обработано строк: 48900
#  Обработано строк: 49000
#  Обработано строк: 49100
#  Обработано строк: 49200
#  Обработано строк: 49300
#  Обработано строк: 49400
#  Обработано строк: 49500
#  Обработано строк: 49600
#  Обработано строк: 49700
#  Обработано строк: 49800
#  Обработано строк: 49900
#  Обработано строк: 50000
#  Обработано строк: 50100
#  Обработано строк: 50200
#  Обработано строк: 50300
#  Обработано строк: 50400
#  Обработано строк: 50500
#  Обработано строк: 50600
#  Обработано строк: 50700
#  Обработано строк: 50800
#  Обработано строк: 50900
#  Обработано строк: 51000
#  Обработано строк: 51100
#  Обработано строк: 51200
#  Обработано строк: 51300
#  Обработано строк: 51400
#  Обработано строк: 51500
#  Обработано строк: 51600
#  Обработано строк: 51700
#  Обработано строк: 51800
#  Обработано строк: 51900
#  Обработано строк: 52000
#  Обработано строк: 52100
#  Обработано строк: 52200
#  Обработано строк: 52300
#  Обработано строк: 52400
#  Обработано строк: 52500
#  Обработано строк: 52600
#  Обработано строк: 52700
#  Обработано строк: 52800
#  Обработано строк: 52900
#  Обработано строк: 53000
