# %%
import os
#модуль для работы с ftp
import ftplib
#модуль для работы с zip архивами
from zipfile import *
#Библиотека для работы с Oracle
import cx_Oracle
import pandas as pd
import datetime as dt
import time

# %%
#!!!Важно. Установленная по умолчанию в Canopy версия библиотеки lxml не умеет читать кодировку windows-1251
#Поэтому необходимо скачать с сайта https://pypi.python.org/pypi/lxml последнюю версию (3.7.3) библиотеки 
#Подключаем библиотеку для парсинга XML
import lxml.etree as et

# %%
# Для корректного отображения оракловых сообщений
os.environ['NLS_LANG'] = 'AMERICAN_AMERICA.AL32UTF8'

# %%
gloglist=[]
def log(atext):
    global gloglist
    gloglist.append(time.asctime(time.localtime(time.time()))+' | '+atext+'\n')

# %%
def savelog():
    global gloglist
    logfile=open('z:\\Python\\zakupki\\log.txt','w') #Создаем новый файл в режиме записи
    try:
        logfile.writelines(gloglist)
    finally:
        logfile.close()
    gloglist=[]

# %%
#Процедура скачивает файл filename с указанной директории directory ftp и кладет его по указанному локальному пути 
def download(ftp,directory,loc_filepath,filename):
    ftp.cwd(directory) #Задает текущую директорию на ftp
    loc_file_name=os.path.join(loc_filepath, filename) #конкатенирует имя файла с путем
    #Открывает файл для записи в двоичном формате. Указатель стоит в начале файла. 
    #Создает файл с именем имя_файла, если такового не существует.
    f = open(loc_file_name,"wb")
    #Получить файл в двоичном режиме. Команда должна иметь соответствующую команду RETR: 'RETR имя_файла'.
    ftp.retrbinary("RETR " + filename,f.write)
    f.close()

# %%
#Функция возвращает список файлов или папок в указанной директории на ftp
def get_ftp_dir_list(ftp, ftp_path):
    ftp.cwd(ftp_path) #Задает текущую директорию на ftp
    llist = []
    #Получение файла или каталога в ASCII режиме передачи. 
    #Команда должна иметь соответствующую команду RETR (см. retrbinary ()) или команду такую как LIST, NLST или MLSD
    ftp.retrlines("LIST", llist.append)
    #т.к. в полученном списке присутствуют все атрибуты файла или папки, надо вычленить только имя
    llist=[s.split(None, 8)[-1].lstrip() for s in llist]
    return llist

# %%
def unzipall(path,archname):
    #Проверяем, является ли указанный файл zip архивом
    if is_zipfile(path + archname):
        #Открываем архив на чтение
        z = ZipFile(path + archname, 'r')
        #Распаковываем все файлы из архива по указанному пути
        z.extractall(path)
        #Возвращаем список файлов в архиве
        return z.namelist()
        z.close()
    else:
        print('Некорректный архив : ' +  archname)

# %%
def str_to_date(astrdate):
    #Даты в xml пишутся по разному. 2015-01-16T00:00:00 или 2015-01-16
    if len(astrdate)==0:
        return None
    elif astrdate[0].text[0]=='0':
        return None
    elif ('T' in astrdate[0].text):
        return dt.datetime.strptime(astrdate[0].text, '%Y-%m-%dT%H:%M:%S')
    else:
        return dt.datetime.strptime(astrdate[0].text, '%Y-%m-%d')

# %%
def xpath_nulls(atag_value):
    if len(atag_value)==0:
        return None
    else:
        return atag_value[0].text

# %%
def xpath_float(atag_value):
    if len(atag_value)==0:
        return 0
    else:
        return float(atag_value[0].text)

# %%
#Функция парсинга xml
def parse_xml(afile, adoc):
    #парсим файл XML и создаем дерево елементов element tree
    etxml = et.parse(afile)
    #получаем корневой элемент дерева
    root=etxml.getroot()
    #Данный цикл позволяет получить список всех элементов (тэгов) дерева, названий и значений
    #Это особенно актуально, когда перед элементом указывается пространство имен (name space), например
    #{http://zakupki.gov.ru/223fz/contract/1}contractRegNumber
    #Это нужно при поиске конкретных тэгов с помощью функций xpath и findall
    #for item in root.iterfind('.//'):
    #    print item.tag + '  :  ' + item.text
    #В аргументе функции xpath указываем строку для поиска, здесь './/' означает, 
    #что надо искать не только среди потомков корневого элемента, но во всех элементах дерева вообще
    #также перечисляем все пространства имен, используемые перед названием тэга, их можно взять из заголовка xml
    #они находятся после ключа xmlns= (для тэгов без указания пространства имен, например <inn>5260267654</inn>) 
    #или xmlns: (для тэгов с указанием пространтства имен, например <ns2:code>40000</ns2:code> ), 
    #сами название пространств имен в xpath не обязательно должны совпадать с xml, но пути и URL должны совпадать
    if adoc=='protocolvk':
        lnamespaces={'ns2' : 'http://zakupki.gov.ru/223fz/purchase/1', 'ns':'http://zakupki.gov.ru/223fz/types/1'}
        acontract=[ 
            root.xpath('.//ns2:purchaseInfo/ns:purchaseNoticeNumber',namespaces=lnamespaces)[0].text,
            root.xpath('.//ns2:purchaseInfo/ns:purchaseMethodCode',namespaces=lnamespaces)[0].text,
            root.xpath('.//ns2:purchaseInfo/ns:purchaseCodeName',namespaces=lnamespaces)[0].text,
            [s.text for s in root.xpath('.//ns2:lotApplicationsList/ns2:protocolLotApplications/ns2:application/ns2:supplierInfo/ns:name',namespaces=lnamespaces)],
            ]
    #Альтернативная xpath функция, но с меньшими возможностями и немного отличным синтаксисом поискового запроса
    #lm = root.findall('.//{http://zakupki.gov.ru/223fz/contract/1}contractRegNumber')
    return acontract

# %%
def compdate(afname,adfrom,adto):
    ifrom=afname.find('_000000_')
    if ifrom==-1:
        return False
    else:
        ldfile=afname[ifrom+8:ifrom+16]
        return dt.datetime.strptime(adfrom, '%Y%m%d')\
               <=dt.datetime.strptime(ldfile, '%Y%m%d')\
               <=dt.datetime.strptime(adto, '%Y%m%d')

# %%
def complists(alist1, alist2):
    for i in alist1:
        for j in alist2:
            si=unicode(i)+'.'
            sj=unicode(j)+'.'
            if si.find(sj)==0:
                return True
    return False

# %%
#Загружаем все файлы с ftp госзакупок из подпапки ftp_dir  в локальную папку lxmlpath
#def gz_get_ftp_files(ftp, ftp_dir, lxmlpath, adf_orgs, adoc, adfrom, adto, aregions=None):
def gz_get_ftp_files(ftp, ftp_dir, lxmlpath, anotices, adoc, adfrom, adto, aregions=None):
    #создаем DataFrame для данных контрактов
    contracts=pd.DataFrame(columns=['nnumber','mcode','mname','nsupplier','ncount',
                                    'zip','xml','region'])
    for s in get_ftp_dir_list(ftp,"/out/published/"):
        i=0
        #s=get_ftp_dir_list(ftp, "/out/published/")[0]
        if aregions==None or ((aregions!=None) and (s in aregions)):
            try:
                lpath="/out/published/" + s + ftp_dir
                time.asctime(time.localtime(time.time()))
                print(time.asctime(time.localtime(time.time())) + ' | Каталог: ' + s)
                ftp.cwd(lpath)
                lftplist=get_ftp_dir_list(ftp, lpath)
                print('Всего файлов (архивов) в FTP каталоге: ' +str(len(lftplist)))
                for f in lftplist:
                    if (f[-4:]=='.zip') and compdate(f,adfrom,adto):
                        log(f)
                        download(ftp, lpath,lxmlpath,f)
                        i+=1
                        archlist=unzipall(lxmlpath,f)
                        #Поскольку в разных архивах содержатся XML файлы с одинаковыми названиями 
                        #- добавляем к названию файла уникальный для архива номер, либо после парсинга сразу удаляем файл XML
                        for x in archlist:
                            #если файл не нулевой длины - парсим xml и загружаем данные в DataFrame
                            if os.path.getsize(lxmlpath + x)!= 0:
                                log(x)
                                contract=parse_xml(lxmlpath + x, adoc)
                                # Удаляем дубли в списке оквэд
                                if contract[0] in anotices:
                                    #добавляем имена файлов zip и xml в список
                                    contract.append(len(contract[3]))
                                    contract.append(f)
                                    contract.append(x)
                                    contract.append(s)
                                    #Могут досылать исправленные данные по контракту в разные дни. Это надо обрабатывать.
                                    #!!!Данный функционал работает не стабильно!!!
                                    #Если мы присваиваем один DataFrame другому или один List другому с помощью оператора =, 
                                    #то в этом случае объект остается один и тот же. Копируется только ссылка на него
                                    #Функция copy() и list() позволяет скопировать физически сам объект и избежать сообщения:
                                    #A value is trying to be set on a copy of a slice from a DataFrame
                                    #tmpdf=contracts[(contracts['number']==contract[0])&(contracts['date']==contract[1])].copy()
                                    #if len(tmpdf.index)!=0:
                                    #    tmpdf.loc[0]=list(contract)
                                    #    contracts.loc[contracts[(contracts['number']==contract[0])&(contracts['date']==contract[1])].index,tmpdf.columns]=tmpdf.copy()
                                    #    print str(contracts[(contracts['number']==contract[0])&(contracts['date']==contract[1])].index)+' upd '.join(list(map(unicode,contract)))
                                    #else:
                                    contracts.loc[len(contracts)]=contract
                                    #    print ' add '.join(list(map(unicode,contract)))
                                #os.rename(lxmlpath + x,lxmlpath + x[:-4] + '_' + str(i) + x[-4:])
                            os.remove(lxmlpath + x)    
                        #удаляем файл архива    
                        os.remove(lxmlpath + f)
                        if i%100==0:
                            print(time.asctime(time.localtime(time.time())) 
                            + ' | Обработано '+str(i)+' файлов из '+str(len(lftplist)) 
                            +' ('+str(int(round(float(i)/len(lftplist)*100)))+'%)')
            except ftplib.error_perm:
                print('В папке ' + s + ' каталог ' + ftp_dir + ' не существует!')
    #Могут досылать исправленные данные по контракту в разные дни. Это надо обрабатывать.
    contracts=contracts.drop_duplicates(['nnumber'],keep='last')
    contracts.index=range(len(contracts.index))
    print(u'Окончание обработки: '+time.asctime(time.localtime(time.time())))
    savelog()
    return contracts

# %%
#Блок подготовки и проверки SQL команды
def insert_prepare(asql,acursor):
    try:
        acursor.prepare(asql)
    except cx_Oracle.DatabaseError as exception:
        print('Failed to prepare cursor')
        print(exception)
        exit(1)

# %%
def load_from_ora(asql):    
    conn=cx_Oracle.connect('analytics/analytics@fst_rac')
    cursor=conn.cursor()
    try:
        insert_prepare(asql,cursor)
        try:
            cursor.execute(cursor.statement)
            ltable=cursor.fetchall()
            #получаем названия полей запроса
            lcols=[col_desc[0] for col_desc in cursor.description]
        except cx_Oracle.DatabaseError as exception:
            print('Failed to insert row')
            print(exception)
            print(cursor.statement)
            exit(1)
        df=pd.DataFrame(ltable, columns=lcols)
        return df
    finally:
        cursor.close()
        conn.close()

# %%
def load_df_to_ora(adf):
    conn=cx_Oracle.connect('analytics/analytics@fst_rac')
    cursor=conn.cursor()
    try:
        isql = """
                  INSERT INTO ZAKUPKI_PROTOKOLVK 
                  (nnumber, mcode, mname, nsupplier, ncount, zip, nxml, nregion) 
                  VALUES (:s_nnumber, :s_mcode, :s_mname, :s_nsupplier, :s_ncount, :s_zip, :s_nxml, :s_nregion)
               """
        #Блок подготовки и проверки SQL команды
        for i in range(len(adf.index)):
            #if adf['NOTICENUM'][i]=='NULL':
            insert_prepare(isql,cursor)
            #else:
            #    insert_prepare(usql,cursor)
            try:
                #Выполнение Insert
                cursor.execute (cursor.statement,s_nnumber=adf['nnumber'][i],
                                s_mcode=adf['mcode'][i],s_mname=adf['mname'][i],
                                s_nsupplier=None,s_ncount=adf['ncount'][i],
                                s_zip=adf['zip'][i],s_nxml=adf['xml'][i], s_nregion=adf['region'][i]
                                )
            except cx_Oracle.DatabaseError as exception:
                print('Failed to insert row')
                print(exception)
                print(cursor.statement)
                #print str(df['NYEAR'][i])+'|'+str(df['GROUP_NUMBER'][i])+'|'+str(df['GROUP_NAME'][i])+'|'+str(df['ORG_REG_NUMBER'][i])+'|'+str(df['ORG_NAME'][i])
                exit(1)
            if (i>0) and (i%100==0):
                print(u' Обработано строк: '+str(i))
        conn.commit()   
    finally:
        cursor.close()
        conn.close()

# %%
sql=u"""
    select noticenum
    from analytics.ZAKUPKI_SMP
    """      
df_notices=load_from_ora(sql)

# %%
def ftpconnect():
    #создаем объект ftp для заданного адреса ftp-сервера
    lftp = ftplib.FTP("ftp.zakupki.gov.ru")
    #коннектимся к серверу с именем пользователя и паролем
    lftp.login("fz223free", "fz223free")
    return lftp

# %%
ftp=ftpconnect()
get_ftp_dir_list(ftp,'/out/published/')
# Out:
# ['Adygeya_Resp',
#  'Altay_Resp',
#  'Altayskii__krai',
#  'Amurskaya_obl',
#  'Arhangelskaya_obl',
#  'Astrahanskaya_obl',
#  'Baikonur_g',
#  'Bashkortostan_Resp',
#  'Belgorodskaya_obl',
#  'Brianskaya_obl',
#  'Buryatiya_Resp',
#  'Chechenskaya_Resp',
#  'Cheliabinskaya_obl',
#  'Chukotskii_AO',
#  'Chuvashskaya_Respublika',
#  'Dagestan_Resp',
#  'Evreiskaya_Aobl',
#  'Habarovskii_krai',
#  'Hakasiia_Resp',
#  'Hanty-Mansiiskii_AO_Iugra_AO',
#  'Ingushetiya_Resp',
#  'Irkutskaya_obl',
#  'Irkutskaya_obl_Ust-Ordynskii_Buriatskii_okrug',
#  'Ivanowskaya_obl',
#  'Jamalo-Nenetckii_AO',
#  'Jaroslavskaya_obl',
#  'Kabardino-Balkarskaya_Resp',
#  'Kaliningradskaya_obl',
#  'Kalmykiya_Resp',
#  'Kaluzhskaya_obl',
#  'Kamchatskii_krai',
#  'Karachaevo-Cherkesskaya_Resp',
#  'Kareliya_Resp',
#  'Kemerowskaya_obl',
#  'Kirowskaya_obl',
#  'Komi_Resp',
#  'Kostromskaya_obl',
#  'Krasnodarskii_krai',
#  'Krasnoyarskii_krai',
#  'Krym_Resp',
#  'Kurganskaya_obl',
#  'Kurskaya_obl',
#  'Leningradskaya_obl',
#  'Lipetckaya_obl',
#  'Magadanskaya_obl',
#  'Marii_El_Resp',
#  'Mordoviya_Resp',
#  'Moskovskaya_obl',
#  'Moskva',
#  'Murmanskaya_obl',
#  'Nenetckii_AO',
#  'Nizhegorodskaya_obl',
#  'Novgorodskaya_obl',
#  'Novosibirskaya_obl',
#  'Omskaya_obl',
#  'Orenburgskaya_obl',
#  'Orlovskaya_obl',
#  'Penzenskaya_obl',
#  'Permskii_krai',
#  'Primorskii_krai',
#  'Pskovskaya_obl',
#  'Rostovskaya_obl',
#  'Ryazanskaya_obl',
#  'Saha_Jakutiya_Resp',
#  'Sahalinskaya_obl',
#  'Samarskaya_obl',
#  'Sankt-Peterburg',
#  'Saratovskaya_obl',
#  'Sevastopol',
#  'Severnaia_Osetiya_Alaniia_Resp',
#  'Smolenskaya_obl',
#  'Stavropolskii_krai',
#  'Sverdlovskaya_obl',
#  'Tambovskaya_obl',
#  'Tatarstan_Resp',
#  'Tiumenskaya_obl',
#  'Tomskaya_obl',
#  'Tulskaya_obl',
#  'Tverskaya_obl',
#  'Tyva_Resp',
#  'Udmurtskaya_Resp',
#  'Ulianovskaya_obl',
#  'Vladimirskaya_obl',
#  'Volgogradskaya_obl',
#  'Vologodskaya_obl',
#  'Voronezhskaya_obl',
#  'Zabaikalskii_krai',
#  'Zabaikalskii_krai_Aginskii_Buriatskii_okrug',
#  'archive',
#  'undefined']

# %%
lreglist=[
 'Adygeya_Resp',
 'Altay_Resp',
 'Altayskii__krai',
 'Amurskaya_obl',
 'Arhangelskaya_obl',
 'Astrahanskaya_obl',
 'Baikonur_g',
 'Bashkortostan_Resp',
 'Belgorodskaya_obl',
 'Brianskaya_obl',
 'Buryatiya_Resp',
 'Chechenskaya_Resp',
 'Cheliabinskaya_obl',
 'Chukotskii_AO',
 'Chuvashskaya_Respublika',
 'Dagestan_Resp',
 'Evreiskaya_Aobl',
 'Habarovskii_krai',
 'Hakasiia_Resp',
 'Hanty-Mansiiskii_AO_Iugra_AO',
 'Ingushetiya_Resp',
 'Irkutskaya_obl',
 'Irkutskaya_obl_Ust-Ordynskii_Buriatskii_okrug',
 'Ivanowskaya_obl',
 'Jamalo-Nenetckii_AO',
 'Jaroslavskaya_obl',
 'Kabardino-Balkarskaya_Resp',
 'Kaliningradskaya_obl',
 'Kalmykiya_Resp',
 'Kaluzhskaya_obl',
 'Kamchatskii_krai',
 'Karachaevo-Cherkesskaya_Resp',
 'Kareliya_Resp',
 'Kemerowskaya_obl',
 'Kirowskaya_obl',
 'Komi_Resp',
 'Kostromskaya_obl',
 'Krasnodarskii_krai',
 'Krasnoyarskii_krai',
 'Krym_Resp',
 'Kurganskaya_obl',
 'Kurskaya_obl',
 'Leningradskaya_obl',
 'Lipetckaya_obl',
 'Magadanskaya_obl',
 'Marii_El_Resp',
 'Mordoviya_Resp',
 'Moskovskaya_obl',
 'Moskva',
 'Murmanskaya_obl',
 'Nenetckii_AO',
 'Nizhegorodskaya_obl',
 'Novgorodskaya_obl',
 'Novosibirskaya_obl',
 'Omskaya_obl',
 'Orenburgskaya_obl',
 'Orlovskaya_obl',
 'Penzenskaya_obl',
 'Permskii_krai',
 'Primorskii_krai',
 'Pskovskaya_obl',
 'Rostovskaya_obl',
 'Ryazanskaya_obl',
 'Saha_Jakutiya_Resp',
 'Sahalinskaya_obl',
 'Samarskaya_obl',
 'Sankt-Peterburg',
 'Saratovskaya_obl',
 'Sevastopol',
 'Severnaia_Osetiya_Alaniia_Resp',
 'Smolenskaya_obl',
 'Stavropolskii_krai',
 'Sverdlovskaya_obl',
 'Tambovskaya_obl',
 'Tatarstan_Resp',
 'Tiumenskaya_obl',
 'Tomskaya_obl',
 'Tulskaya_obl',
 'Tverskaya_obl',
 'Tyva_Resp',
 'Udmurtskaya_Resp',
 'Ulianovskaya_obl',
 'Vladimirskaya_obl',
 'Volgogradskaya_obl',
 'Vologodskaya_obl',
 'Voronezhskaya_obl',
 'Zabaikalskii_krai',
 'Zabaikalskii_krai_Aginskii_Buriatskii_okrug'
]

# %%
lreglist=[
 'Permskii_krai',
 'Primorskii_krai',
 'Pskovskaya_obl',
 'Rostovskaya_obl',
 'Ryazanskaya_obl',
 'Saha_Jakutiya_Resp',
 'Sahalinskaya_obl',
 'Samarskaya_obl',
 'Sankt-Peterburg',
 'Saratovskaya_obl',
 'Sevastopol',
 'Severnaia_Osetiya_Alaniia_Resp',
 'Smolenskaya_obl',
 'Stavropolskii_krai',
 'Sverdlovskaya_obl',
 'Tambovskaya_obl',
 'Tatarstan_Resp',
 'Tiumenskaya_obl',
 'Tomskaya_obl',
 'Tulskaya_obl',
 'Tverskaya_obl',
 'Tyva_Resp',
 'Udmurtskaya_Resp',
 'Ulianovskaya_obl',
 'Vladimirskaya_obl',
 'Volgogradskaya_obl',
 'Vologodskaya_obl',
 'Voronezhskaya_obl',
 'Zabaikalskii_krai',
 'Zabaikalskii_krai_Aginskii_Buriatskii_okrug'
]

# %%
# purchaseProtocolRZOK - протоколы открытого конкурса
# purchaseProtocolRZOA - протоколы открытого аукциона
# purchaseProtocolRZAE - протоколы аукциона в электронной форме
# purchaseProtocol
for reg in lreglist:
    ftp=ftpconnect()
    contracts=gz_get_ftp_files(ftp, "/purchaseProtocol/daily/", "z:\\Python\\zakupki\\contracts_xml\\",df_notices.NOTICENUM.tolist(),
                          'protocolvk','20180101','20180831',[reg])
    load_df_to_ora(contracts)
# Out:
# Tue Oct 09 12:57:44 2018 | Каталог: Permskii_krai
# Всего файлов (архивов) в FTP каталоге: 2717
# Tue Oct 09 12:58:25 2018 | Обработано 100 файлов из 2717 (4%)
# Tue Oct 09 12:59:09 2018 | Обработано 200 файлов из 2717 (7%)
# Tue Oct 09 12:59:45 2018 | Обработано 300 файлов из 2717 (11%)
# Окончание обработки: Tue Oct 09 12:59:58 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
#  Обработано строк: 1300
#  Обработано строк: 1400
#  Обработано строк: 1500
#  Обработано строк: 1600
#  Обработано строк: 1700
#  Обработано строк: 1800
#  Обработано строк: 1900
#  Обработано строк: 2000
#  Обработано строк: 2100
#  Обработано строк: 2200
# Tue Oct 09 13:00:08 2018 | Каталог: Primorskii_krai
# Всего файлов (архивов) в FTP каталоге: 1802
# Tue Oct 09 13:00:54 2018 | Обработано 100 файлов из 1802 (6%)
# Tue Oct 09 13:01:32 2018 | Обработано 200 файлов из 1802 (11%)
# Окончание обработки: Tue Oct 09 13:01:34 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
#  Обработано строк: 1300
#  Обработано строк: 1400
#  Обработано строк: 1500
#  Обработано строк: 1600
# Tue Oct 09 13:01:42 2018 | Каталог: Pskovskaya_obl
# Всего файлов (архивов) в FTP каталоге: 1640
# Tue Oct 09 13:01:52 2018 | Обработано 100 файлов из 1640 (6%)
# Tue Oct 09 13:02:02 2018 | Обработано 200 файлов из 1640 (12%)
# Окончание обработки: Tue Oct 09 13:02:03 2018
#  Обработано строк: 100
#  Обработано строк: 200
# Tue Oct 09 13:02:04 2018 | Каталог: Rostovskaya_obl
# Всего файлов (архивов) в FTP каталоге: 2924
# Tue Oct 09 13:02:55 2018 | Обработано 100 файлов из 2924 (3%)
# Tue Oct 09 13:03:40 2018 | Обработано 200 файлов из 2924 (7%)
# Tue Oct 09 13:04:14 2018 | Обработано 300 файлов из 2924 (10%)
# Окончание обработки: Tue Oct 09 13:04:24 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
#  Обработано строк: 1300
#  Обработано строк: 1400
#  Обработано строк: 1500
#  Обработано строк: 1600
#  Обработано строк: 1700
#  Обработано строк: 1800
#  Обработано строк: 1900
#  Обработано строк: 2000
#  Обработано строк: 2100
#  Обработано строк: 2200
#  Обработано строк: 2300
#  Обработано строк: 2400
#  Обработано строк: 2500
#  Обработано строк: 2600
#  Обработано строк: 2700
# Tue Oct 09 13:04:36 2018 | Каталог: Ryazanskaya_obl
# Всего файлов (архивов) в FTP каталоге: 2442
# Tue Oct 09 13:05:00 2018 | Обработано 100 файлов из 2442 (4%)
# Tue Oct 09 13:05:24 2018 | Обработано 200 файлов из 2442 (8%)
# Tue Oct 09 13:05:41 2018 | Обработано 300 файлов из 2442 (12%)
# Окончание обработки: Tue Oct 09 13:05:42 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
# Tue Oct 09 13:05:46 2018 | Каталог: Saha_Jakutiya_Resp
# Всего файлов (архивов) в FTP каталоге: 2295
# Tue Oct 09 13:06:52 2018 | Обработано 100 файлов из 2295 (4%)
# Окончание обработки: Tue Oct 09 13:07:39 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
#  Обработано строк: 1300
#  Обработано строк: 1400
#  Обработано строк: 1500
#  Обработано строк: 1600
#  Обработано строк: 1700
# Tue Oct 09 13:07:47 2018 | Каталог: Sahalinskaya_obl
# Всего файлов (архивов) в FTP каталоге: 1634
# Tue Oct 09 13:08:17 2018 | Обработано 100 файлов из 1634 (6%)
# Окончание обработки: Tue Oct 09 13:08:30 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
# Tue Oct 09 13:08:32 2018 | Каталог: Samarskaya_obl
# Всего файлов (архивов) в FTP каталоге: 2918
# Tue Oct 09 13:09:18 2018 | Обработано 100 файлов из 2918 (3%)
# Tue Oct 09 13:10:05 2018 | Обработано 200 файлов из 2918 (7%)
# Tue Oct 09 13:10:39 2018 | Обработано 300 файлов из 2918 (10%)
# Окончание обработки: Tue Oct 09 13:10:48 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
#  Обработано строк: 1300
#  Обработано строк: 1400
#  Обработано строк: 1500
#  Обработано строк: 1600
#  Обработано строк: 1700
#  Обработано строк: 1800
#  Обработано строк: 1900
#  Обработано строк: 2000
#  Обработано строк: 2100
#  Обработано строк: 2200
#  Обработано строк: 2300
#  Обработано строк: 2400
#  Обработано строк: 2500
#  Обработано строк: 2600
# Tue Oct 09 13:10:59 2018 | Каталог: Sankt-Peterburg
# Всего файлов (архивов) в FTP каталоге: 3197
# Tue Oct 09 13:14:04 2018 | Обработано 100 файлов из 3197 (3%)
# Tue Oct 09 13:17:23 2018 | Обработано 200 файлов из 3197 (6%)
# Окончание обработки: Tue Oct 09 13:18:00 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
#  Обработано строк: 1300
#  Обработано строк: 1400
#  Обработано строк: 1500
#  Обработано строк: 1600
#  Обработано строк: 1700
#  Обработано строк: 1800
#  Обработано строк: 1900
#  Обработано строк: 2000
#  Обработано строк: 2100
#  Обработано строк: 2200
#  Обработано строк: 2300
#  Обработано строк: 2400
#  Обработано строк: 2500
#  Обработано строк: 2600
#  Обработано строк: 2700
#  Обработано строк: 2800
#  Обработано строк: 2900
#  Обработано строк: 3000
#  Обработано строк: 3100
#  Обработано строк: 3200
#  Обработано строк: 3300
#  Обработано строк: 3400
#  Обработано строк: 3500
#  Обработано строк: 3600
#  Обработано строк: 3700
#  Обработано строк: 3800
#  Обработано строк: 3900
#  Обработано строк: 4000
#  Обработано строк: 4100
#  Обработано строк: 4200
#  Обработано строк: 4300
#  Обработано строк: 4400
#  Обработано строк: 4500
#  Обработано строк: 4600
#  Обработано строк: 4700
#  Обработано строк: 4800
#  Обработано строк: 4900
#  Обработано строк: 5000
#  Обработано строк: 5100
#  Обработано строк: 5200
#  Обработано строк: 5300
#  Обработано строк: 5400
#  Обработано строк: 5500
#  Обработано строк: 5600
#  Обработано строк: 5700
#  Обработано строк: 5800
#  Обработано строк: 5900
#  Обработано строк: 6000
#  Обработано строк: 6100
#  Обработано строк: 6200
#  Обработано строк: 6300
#  Обработано строк: 6400
#  Обработано строк: 6500
#  Обработано строк: 6600
#  Обработано строк: 6700
#  Обработано строк: 6800
#  Обработано строк: 6900
#  Обработано строк: 7000
# Tue Oct 09 13:18:32 2018 | Каталог: Saratovskaya_obl
# Всего файлов (архивов) в FTP каталоге: 3015
# Tue Oct 09 13:19:34 2018 | Обработано 100 файлов из 3015 (3%)
# Tue Oct 09 13:20:36 2018 | Обработано 200 файлов из 3015 (7%)
# Tue Oct 09 13:21:17 2018 | Обработано 300 файлов из 3015 (10%)
# Окончание обработки: Tue Oct 09 13:21:31 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
#  Обработано строк: 1300
#  Обработано строк: 1400
#  Обработано строк: 1500
#  Обработано строк: 1600
#  Обработано строк: 1700
#  Обработано строк: 1800
#  Обработано строк: 1900
#  Обработано строк: 2000
#  Обработано строк: 2100
#  Обработано строк: 2200
#  Обработано строк: 2300
#  Обработано строк: 2400
#  Обработано строк: 2500
#  Обработано строк: 2600
#  Обработано строк: 2700
#  Обработано строк: 2800
#  Обработано строк: 2900
#  Обработано строк: 3000
#  Обработано строк: 3100
#  Обработано строк: 3200
# Tue Oct 09 13:21:47 2018 | Каталог: Sevastopol
# Всего файлов (архивов) в FTP каталоге: 1335
# Tue Oct 09 13:21:59 2018 | Обработано 100 файлов из 1335 (7%)
# Окончание обработки: Tue Oct 09 13:22:08 2018
#  Обработано строк: 100
#  Обработано строк: 200
# Tue Oct 09 13:22:09 2018 | Каталог: Severnaia_Osetiya_Alaniia_Resp
# Всего файлов (архивов) в FTP каталоге: 1082
# Tue Oct 09 13:22:20 2018 | Обработано 100 файлов из 1082 (9%)
# Окончание обработки: Tue Oct 09 13:22:21 2018
# Tue Oct 09 13:22:21 2018 | Каталог: Smolenskaya_obl
# Всего файлов (архивов) в FTP каталоге: 2305
# Tue Oct 09 13:22:45 2018 | Обработано 100 файлов из 2305 (4%)
# Tue Oct 09 13:23:04 2018 | Обработано 200 файлов из 2305 (9%)
# Окончание обработки: Tue Oct 09 13:23:15 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
# Tue Oct 09 13:23:18 2018 | Каталог: Stavropolskii_krai
# Всего файлов (архивов) в FTP каталоге: 2811
# Tue Oct 09 13:24:02 2018 | Обработано 100 файлов из 2811 (4%)
# Tue Oct 09 13:24:33 2018 | Обработано 200 файлов из 2811 (7%)
# Окончание обработки: Tue Oct 09 13:24:50 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
# Tue Oct 09 13:24:57 2018 | Каталог: Sverdlovskaya_obl
# Всего файлов (архивов) в FTP каталоге: 2945
# Tue Oct 09 13:26:44 2018 | Обработано 100 файлов из 2945 (3%)
# Tue Oct 09 13:28:39 2018 | Обработано 200 файлов из 2945 (7%)
# Tue Oct 09 13:29:50 2018 | Обработано 300 файлов из 2945 (10%)
# Окончание обработки: Tue Oct 09 13:30:14 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
#  Обработано строк: 1300
#  Обработано строк: 1400
#  Обработано строк: 1500
#  Обработано строк: 1600
#  Обработано строк: 1700
#  Обработано строк: 1800
#  Обработано строк: 1900
#  Обработано строк: 2000
#  Обработано строк: 2100
#  Обработано строк: 2200
#  Обработано строк: 2300
#  Обработано строк: 2400
#  Обработано строк: 2500
#  Обработано строк: 2600
#  Обработано строк: 2700
#  Обработано строк: 2800
#  Обработано строк: 2900
#  Обработано строк: 3000
#  Обработано строк: 3100
#  Обработано строк: 3200
#  Обработано строк: 3300
#  Обработано строк: 3400
#  Обработано строк: 3500
#  Обработано строк: 3600
#  Обработано строк: 3700
#  Обработано строк: 3800
#  Обработано строк: 3900
#  Обработано строк: 4000
#  Обработано строк: 4100
#  Обработано строк: 4200
#  Обработано строк: 4300
#  Обработано строк: 4400
#  Обработано строк: 4500
#  Обработано строк: 4600
#  Обработано строк: 4700
#  Обработано строк: 4800
#  Обработано строк: 4900
#  Обработано строк: 5000
#  Обработано строк: 5100
#  Обработано строк: 5200
#  Обработано строк: 5300
#  Обработано строк: 5400
#  Обработано строк: 5500
#  Обработано строк: 5600
#  Обработано строк: 5700
#  Обработано строк: 5800
#  Обработано строк: 5900
#  Обработано строк: 6000
#  Обработано строк: 6100
#  Обработано строк: 6200
#  Обработано строк: 6300
#  Обработано строк: 6400
#  Обработано строк: 6500
# Tue Oct 09 13:30:42 2018 | Каталог: Tambovskaya_obl
# Всего файлов (архивов) в FTP каталоге: 2233
# Tue Oct 09 13:31:01 2018 | Обработано 100 файлов из 2233 (4%)
# Tue Oct 09 13:31:16 2018 | Обработано 200 файлов из 2233 (9%)
# Окончание обработки: Tue Oct 09 13:31:24 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
# Tue Oct 09 13:31:26 2018 | Каталог: Tatarstan_Resp
# Всего файлов (архивов) в FTP каталоге: 2976
# Tue Oct 09 13:32:21 2018 | Обработано 100 файлов из 2976 (3%)
# Окончание обработки: Tue Oct 09 13:33:04 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
#  Обработано строк: 1300
#  Обработано строк: 1400
#  Обработано строк: 1500
#  Обработано строк: 1600
#  Обработано строк: 1700
#  Обработано строк: 1800
#  Обработано строк: 1900
#  Обработано строк: 2000
#  Обработано строк: 2100
# Tue Oct 09 13:33:21 2018 | Каталог: Tiumenskaya_obl
# Всего файлов (архивов) в FTP каталоге: 2807
# Tue Oct 09 13:34:20 2018 | Обработано 100 файлов из 2807 (4%)
# Tue Oct 09 13:35:31 2018 | Обработано 200 файлов из 2807 (7%)
# Tue Oct 09 13:36:06 2018 | Обработано 300 файлов из 2807 (11%)
# Окончание обработки: Tue Oct 09 13:36:10 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
#  Обработано строк: 1300
#  Обработано строк: 1400
#  Обработано строк: 1500
#  Обработано строк: 1600
#  Обработано строк: 1700
#  Обработано строк: 1800
#  Обработано строк: 1900
#  Обработано строк: 2000
#  Обработано строк: 2100
#  Обработано строк: 2200
#  Обработано строк: 2300
#  Обработано строк: 2400
#  Обработано строк: 2500
#  Обработано строк: 2600
#  Обработано строк: 2700
# Tue Oct 09 13:36:23 2018 | Каталог: Tomskaya_obl
# Всего файлов (архивов) в FTP каталоге: 2569
# Tue Oct 09 13:37:22 2018 | Обработано 100 файлов из 2569 (4%)
# Tue Oct 09 13:38:29 2018 | Обработано 200 файлов из 2569 (8%)
# Tue Oct 09 13:39:19 2018 | Обработано 300 файлов из 2569 (12%)
# Окончание обработки: Tue Oct 09 13:39:23 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
#  Обработано строк: 1300
#  Обработано строк: 1400
#  Обработано строк: 1500
#  Обработано строк: 1600
#  Обработано строк: 1700
#  Обработано строк: 1800
#  Обработано строк: 1900
#  Обработано строк: 2000
#  Обработано строк: 2100
#  Обработано строк: 2200
#  Обработано строк: 2300
#  Обработано строк: 2400
#  Обработано строк: 2500
#  Обработано строк: 2600
#  Обработано строк: 2700
#  Обработано строк: 2800
#  Обработано строк: 2900
#  Обработано строк: 3000
#  Обработано строк: 3100
#  Обработано строк: 3200
#  Обработано строк: 3300
#  Обработано строк: 3400
# Tue Oct 09 13:39:39 2018 | Каталог: Tulskaya_obl
# Всего файлов (архивов) в FTP каталоге: 2631
# Tue Oct 09 13:40:36 2018 | Обработано 100 файлов из 2631 (4%)
# Tue Oct 09 13:41:32 2018 | Обработано 200 файлов из 2631 (8%)
# Tue Oct 09 13:42:04 2018 | Обработано 300 файлов из 2631 (11%)
# Окончание обработки: Tue Oct 09 13:42:06 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
#  Обработано строк: 1300
#  Обработано строк: 1400
#  Обработано строк: 1500
#  Обработано строк: 1600
#  Обработано строк: 1700
#  Обработано строк: 1800
#  Обработано строк: 1900
#  Обработано строк: 2000
#  Обработано строк: 2100
#  Обработано строк: 2200
#  Обработано строк: 2300
#  Обработано строк: 2400
#  Обработано строк: 2500
#  Обработано строк: 2600
#  Обработано строк: 2700
#  Обработано строк: 2800
#  Обработано строк: 2900
#  Обработано строк: 3000
# Tue Oct 09 13:42:18 2018 | Каталог: Tverskaya_obl
# Всего файлов (архивов) в FTP каталоге: 2217
# Tue Oct 09 13:42:39 2018 | Обработано 100 файлов из 2217 (5%)
# Tue Oct 09 13:43:01 2018 | Обработано 200 файлов из 2217 (9%)
# Окончание обработки: Tue Oct 09 13:43:18 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
# Tue Oct 09 13:43:22 2018 | Каталог: Tyva_Resp
# Всего файлов (архивов) в FTP каталоге: 1059
# Окончание обработки: Tue Oct 09 13:43:33 2018
# Tue Oct 09 13:43:33 2018 | Каталог: Udmurtskaya_Resp
# Всего файлов (архивов) в FTP каталоге: 2363
# Tue Oct 09 13:44:04 2018 | Обработано 100 файлов из 2363 (4%)
# Окончание обработки: Tue Oct 09 13:44:27 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
# Tue Oct 09 13:44:30 2018 | Каталог: Ulianovskaya_obl
# Всего файлов (архивов) в FTP каталоге: 2512
# Tue Oct 09 13:45:03 2018 | Обработано 100 файлов из 2512 (4%)
# Tue Oct 09 13:45:34 2018 | Обработано 200 файлов из 2512 (8%)
# Окончание обработки: Tue Oct 09 13:45:50 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
# Tue Oct 09 13:45:55 2018 | Каталог: Vladimirskaya_obl
# Всего файлов (архивов) в FTP каталоге: 2358
# Tue Oct 09 13:46:10 2018 | Обработано 100 файлов из 2358 (4%)
# Tue Oct 09 13:46:25 2018 | Обработано 200 файлов из 2358 (8%)
# Окончание обработки: Tue Oct 09 13:46:32 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
# Tue Oct 09 13:46:35 2018 | Каталог: Volgogradskaya_obl
# Всего файлов (архивов) в FTP каталоге: 2612
# Tue Oct 09 13:47:07 2018 | Обработано 100 файлов из 2612 (4%)
# Tue Oct 09 13:47:39 2018 | Обработано 200 файлов из 2612 (8%)
# Tue Oct 09 13:48:04 2018 | Обработано 300 файлов из 2612 (11%)
# Окончание обработки: Tue Oct 09 13:48:08 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
# Tue Oct 09 13:48:14 2018 | Каталог: Vologodskaya_obl
# Всего файлов (архивов) в FTP каталоге: 2323
# Tue Oct 09 13:48:32 2018 | Обработано 100 файлов из 2323 (4%)
# Tue Oct 09 13:48:49 2018 | Обработано 200 файлов из 2323 (9%)
# Окончание обработки: Tue Oct 09 13:48:59 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
# Tue Oct 09 13:49:01 2018 | Каталог: Voronezhskaya_obl
# Всего файлов (архивов) в FTP каталоге: 2585
# Tue Oct 09 13:49:35 2018 | Обработано 100 файлов из 2585 (4%)
# Tue Oct 09 13:50:17 2018 | Обработано 200 файлов из 2585 (8%)
# Tue Oct 09 13:50:44 2018 | Обработано 300 файлов из 2585 (12%)
# Окончание обработки: Tue Oct 09 13:50:46 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
#  Обработано строк: 1300
#  Обработано строк: 1400
#  Обработано строк: 1500
#  Обработано строк: 1600
#  Обработано строк: 1700
#  Обработано строк: 1800
#  Обработано строк: 1900
#  Обработано строк: 2000
#  Обработано строк: 2100
# Tue Oct 09 13:50:56 2018 | Каталог: Zabaikalskii_krai
# Всего файлов (архивов) в FTP каталоге: 1959
# Tue Oct 09 13:51:29 2018 | Обработано 100 файлов из 1959 (5%)
# Tue Oct 09 13:51:56 2018 | Обработано 200 файлов из 1959 (10%)
# Окончание обработки: Tue Oct 09 13:52:12 2018
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
# Tue Oct 09 13:52:16 2018 | Каталог: Zabaikalskii_krai_Aginskii_Buriatskii_okrug
# Всего файлов (архивов) в FTP каталоге: 93
# Окончание обработки: Tue Oct 09 13:52:17 2018

# %%
pd.set_option('max_colwidth',150)
contracts
# Out:
#            nnumber   mcode  \
# 0      31705975292  110918
# 1      31705859229     924
# 2      31705912117   28891
# 3      31705904843     924
# 4      31806122511    2068
# 5      31806163022   28873
# 6      31806163059    2068
# 7      31806234213   41086
# 8      31806175178     924
# 9      31705232331  152899
# 10     31705232337  152899
# 11     31806188546    2068
# 12     31806175410     924
# 13     31806223688     924
# 14     31806181544     924
# 15     31806228745    2068
# 16     31806202547     924
# 17     31806188120     924
# 18     31806207948     924
# 19     31806245635     924
# 20     31806294757  191472
# 21     31806228996    2068
# 22     31806188053     924
# 23     31806245592    2068
# 24     31806257569   28891
# 25     31806188421     924
# 26     31806188424     924
# 27     31806213042     924
# 28     31806228735     924
# 29     31806270289     924
# ...            ...     ...
# 17627  31806808201  211302
# 17628  31806668217    8993
# 17629  31806810139  211302
# 17630  31806808185  211302
# 17631  31806808168  211302
# 17632  31806808137  211302
# 17633  31806808115  211302
# 17634  31806846015  211302
# 17635  31806810136   67171
# 17636  31806809529   67171
# 17637  31806795212  109858
# 17638  31806776699    4683
# 17639  31806849751  109862
# 17640  31806800951  118770
# 17641  31806849906  109862
# 17642  31806850073  109862
# 17643  31806855266  109862
# 17644  31806855272  109862
# 17645  31806858414   18346
# 17646  31806858482   18346
# 17647  31806858574   18346
# 17648  31806858623   18346
# 17649  31806827897  109857
# 17650  31806861828  109862
# 17651  31806863062   18346
# 17652  31806863121   18346
# 17653  31806865386  109862
# 17654  31806867644  109862
# 17655  31806872478  109862
# 17656  31806873043  109862
#
#                                                                 mname  \
# 0                                                  Запрос предложений
# 1                                   открытый запрос предложений (ЭТП)
# 2                                           запрос цен открытый (ЭТП)
# 3                                   открытый запрос предложений (ЭТП)
# 4                                           запрос цен открытый (ЭТП)
# 5                                   открытый запрос предложений (ЭТП)
# 6                                           запрос цен открытый (ЭТП)
# 7                                                  Запрос предложений
# 8                                   открытый запрос предложений (ЭТП)
# 9                                                  запрос предложений
# 10                                                 запрос предложений
# 11                                          запрос цен открытый (ЭТП)
# 12                                  открытый запрос предложений (ЭТП)
# 13                                  открытый запрос предложений (ЭТП)
# 14                                  открытый запрос предложений (ЭТП)
# 15                                          запрос цен открытый (ЭТП)
# 16                                  открытый запрос предложений (ЭТП)
# 17                                  открытый запрос предложений (ЭТП)
# 18                                  открытый запрос предложений (ЭТП)
# 19                                  открытый запрос предложений (ЭТП)
# 20                                                 Упрощенная закупка
# 21                                          запрос цен открытый (ЭТП)
# 22                                  открытый запрос предложений (ЭТП)
# 23                                          запрос цен открытый (ЭТП)
# 24                                          запрос цен открытый (ЭТП)
# 25                                  открытый запрос предложений (ЭТП)
# 26                                  открытый запрос предложений (ЭТП)
# 27                                  открытый запрос предложений (ЭТП)
# 28                                  открытый запрос предложений (ЭТП)
# 29                                  открытый запрос предложений (ЭТП)
# ...                                                               ...
# 17627  Закупка с единственным поставщиком (подрядчиком, исполнителем)
# 17628    29 (Газпром) Открытый запрос предложений в электронной форме
# 17629  Закупка с единственным поставщиком (подрядчиком, исполнителем)
# 17630  Закупка с единственным поставщиком (подрядчиком, исполнителем)
# 17631  Закупка с единственным поставщиком (подрядчиком, исполнителем)
# 17632  Закупка с единственным поставщиком (подрядчиком, исполнителем)
# 17633  Закупка с единственным поставщиком (подрядчиком, исполнителем)
# 17634  Закупка с единственным поставщиком (подрядчиком, исполнителем)
# 17635                                                      Запрос цен
# 17636                                                      Запрос цен
# 17637                            Запрос котировок в электронной форме
# 17638                                              Запрос предложений
# 17639                              Закупка у единственного поставщика
# 17640                                                       Редукцион
# 17641                              Закупка у единственного поставщика
# 17642                              Закупка у единственного поставщика
# 17643                              Закупка у единственного поставщика
# 17644                              Закупка у единственного поставщика
# 17645                              Закупка у единственного поставщика
# 17646                              Закупка у единственного поставщика
# 17647                              Закупка у единственного поставщика
# 17648                              Закупка у единственного поставщика
# 17649                               Запрос котировок в бумажной форме
# 17650                              Закупка у единственного поставщика
# 17651                              Закупка у единственного поставщика
# 17652                              Закупка у единственного поставщика
# 17653                              Закупка у единственного поставщика
# 17654                              Закупка у единственного поставщика
# 17655                              Закупка у единственного поставщика
# 17656                              Закупка у единственного поставщика
#
#                                                                                                                                                    nsupplier  \
# 0                                                                                                                                 [ООО "Новомариинский ТПК"]
# 1                                                                                                         [Публичное акционерное общество «Сбербанк России»]
# 2                                                [ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФОРРУС", Общество с ограниченной ответственностью "Нефтехиммаш"]
# 3                                                                                                   [Общество с ограниченной ответственностью «Альбатрос Т»]
# 4                                         [Общество с ограниченной ответственностью "ТехноГарант", Общество с ограниченной ответственностью «Доринжиниринг»]
# 5      [Общество с ограниченной ответственностью «НПП Бреслер", ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ  "Промис", Общество с Ограниченной Ответственнос...
# 6      [Акционерное общество "Холдинговая компания "Энергомаш-Строй", Акционерное общество "Белэнергомашсервис", Общество с ограниченной ответственностью...
# 7                                                                                                                                 [ООО "Новомариинский ТПК"]
# 8                     [Общество с ограниченной ответственностью "Гермес", Общество с ограниченной ответственностью "Завод электротехнического оборудования"]
# 9                                                                                                                                                         []
# 10                                                                                                                                                        []
# 11     [Общество с Ограниченной Ответственностью Производственное Объединение Сибирская Ассоциация Энергетического Машиностроения, ОБЩЕСТВО С ОГРАНИЧЕННО...
# 12     [Общество с ограниченной ответственностью "Поволжский завод энергетического оборудования", Общество с ограниченной ответственностью «Научно-произв...
# 13                                                          [ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ НАУЧНО-ПРОИЗВОДСТВЕННОЕ ПРЕДПРИЯТИЕ "СПЕЦСТРОЙ-СВЯЗЬ"]
# 14     [Общество с ограниченной ответственностью "Восток-УАЗ", Общество с ограниченной ответственностью "ГУД ВИН", Общество с ограниченной ответственност...
# 15                                          [Общество с ограниченной ответственностью "Уралнефтегаз", Общество с ограниченной ответственностью "РЭМ-Энерго"]
# 16     [Общество с ограниченной ответственностью «Южноуральская изоляторная компания», Общество с ограниченной ответственностью ПО "РосЭнергоРесурс", ОБЩ...
# 17     [Общество с ограниченной ответственностью «СТРОЙПРОМ», ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "МВК-КОМПЛЕКТ", Общество с ограниченной ответствен...
# 18     [Общество с ограниченной ответственностью "Торговый дом "ЭНЕРГОГОРОД", Общество с Ограниченной Ответственностью  "ЭНЕРГОКОМПЛЕКТ", Общество с огра...
# 19                                                                                                                         [Акционерное общество "Метролог"]
# 20                                                                                        [Общество с ограниченной ответственностью "Теплоэнергосервис ДКМ"]
# 21              [ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ ФИРМА 'ИНТЕРТЕХНОЛОГИЯ', Общество с Ограниченной ответственностью  «Энергетический Альянс Сибири»]
# 22     [Общество с ограниченной ответственностью  "СТК-Комплект", Акционерное общество "Калужский завод энергетического машиностроения", Общество с огран...
# 23     [ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ ПРОИЗВОДСТВЕННОЕ ОБЪЕДИНЕНИЕ «АЛМАШ», Общество с ограниченной ответственностью "ЭНЕРГОВОСТОК", ОБЩЕСТВО ...
# 24     [Общество с ограниченной ответственностью "ИнТрейд", Общество с ограниченной ответственностью «Сибтеплоэлектрокомплект», Общество с ограниченной о...
# 25     [АКЦИОНЕРНОЕ ОБЩЕСТВО "ЗАВОД КОТЕЛЬНОГО ОБОРУДОВАНИЯ", Общество с ограниченной ответственностью "Барнаульский завод энергетического оборудования",...
# 26     [Общество с ограниченной ответственностью "Барнаульский завод энергетического оборудования", Акционерное общество "Холдинговая компания "Энергомаш...
# 27     [ИП Бухонов Виталий Олегович, Общество с ограниченной ответственностью 'ЭКОСТАНДАРТ 'Технические решения', федеральное государственное бюджетное у...
# 28     [Общество с ограниченной ответственностью "Мастерлит", ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ ПРОИЗВОДСТВЕННОЕ ОБЪЕДИНЕНИЕ «АЛМАШ», Общество с о...
# 29                                                                                                    [Общество с ограниченной ответственностью «НПО ГЕЛАР»]
# ...                                                                                                                                                      ...
# 17627                                                                                                           [МУП «Управление капитального строительства]
# 17628                                                                                                                               [Участник 1, Участник 2]
# 17629                                                                 [Муниципальное учреждение «Управление капитального строительства Буинского района РТ»]
# 17630                                                   [Муниципальное унитарное предприятие «Служба единого заказчика» Сабинского муниципального района РТ]
# 17631                                    [Муниципальное унитарное предприятие «Центр капитального строительства Пестречинского района Республики Татарстан»]
# 17632                                   [Муниципальное автономное учреждение «Отдел капитального строительства и архитектуры Арского муниципального района»]
# 17633                                                                                                         [Муниципальное унитарное предприятие «Гарант»]
# 17634                                                                                                  [Общество с ограниченной ответственностью «Водстрой»]
# 17635                                                                                                                    [ООО «АВР ФАСИЛИТИ СЕРВИС КОМПАНИ»]
# 17636                                                                                               [ООО «АВР ФАСИЛИТИ СЕРВИС КОМПАНИ» , ООО 'СК 'ТехВент' ]
# 17637                                                                                                                                                     []
# 17638  [ООО "МИР ТРУБ", ООО "Татсвязькомплект"  , ООО «ТЗПТ», ООО "МИР ТРУБ" , ООО «ТЗПТ», ООО "МИР ТРУБ" , ООО «ТЗПТ», ООО "МИР ТРУБ" , ООО "Татсвязьком...
# 17639                                                                                                                                                     []
# 17640  [Акционерное общество "Стройтех", ООО "Дексис", ООО "РЕАКТИВ", Общество с ограниченной ответственностью "БББ-ИНК", ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТ...
# 17641                                                                                                                                                     []
# 17642                                                                                                                                                     []
# 17643                                                                                                                                                     []
# 17644                                                                                                                                                     []
# 17645                                                                                                                                                     []
# 17646                                                                                                                                                     []
# 17647                                                                                                                                                     []
# 17648                                                                                                                                                     []
# 17649                                                                                                                                     [ООО «НПП «Альфа»]
# 17650                                                                                                                                                     []
# 17651                                                                                                                                                     []
# 17652                                                                                                                                                     []
# 17653                                                                                                                                                     []
# 17654                                                                                                                                                     []
# 17655                                                                                                                                                     []
# 17656                                                                                                                                                     []
#
#        ncount  \
# 0         1.0
# 1         1.0
# 2         2.0
# 3         1.0
# 4         2.0
# 5         4.0
# 6         6.0
# 7         1.0
# 8         2.0
# 9         0.0
# 10        0.0
# 11        6.0
# 12        2.0
# 13        1.0
# 14        4.0
# 15        2.0
# 16        8.0
# 17        3.0
# 18        5.0
# 19        1.0
# 20        1.0
# 21        2.0
# 22        6.0
# 23        4.0
# 24        9.0
# 25        4.0
# 26        2.0
# 27        3.0
# 28        3.0
# 29        1.0
# ...       ...
# 17627     1.0
# 17628     2.0
# 17629     1.0
# 17630     1.0
# 17631     1.0
# 17632     1.0
# 17633     1.0
# 17634     1.0
# 17635     1.0
# 17636     2.0
# 17637     0.0
# 17638    13.0
# 17639     0.0
# 17640     5.0
# 17641     0.0
# 17642     0.0
# 17643     0.0
# 17644     0.0
# 17645     0.0
# 17646     0.0
# 17647     0.0
# 17648     0.0
# 17649     1.0
# 17650     0.0
# 17651     0.0
# 17652     0.0
# 17653     0.0
# 17654     0.0
# 17655     0.0
# 17656     0.0
#
#                                                                                      zip  \
# 0       purchaseProtocol_Chukotskii_AO_20180111_000000_20180111_235959_daily_001.xml.zip
# 1       purchaseProtocol_Chukotskii_AO_20180112_000000_20180112_235959_daily_001.xml.zip
# 2       purchaseProtocol_Chukotskii_AO_20180115_000000_20180115_235959_daily_001.xml.zip
# 3       purchaseProtocol_Chukotskii_AO_20180118_000000_20180118_235959_daily_001.xml.zip
# 4       purchaseProtocol_Chukotskii_AO_20180305_000000_20180305_235959_daily_001.xml.zip
# 5       purchaseProtocol_Chukotskii_AO_20180316_000000_20180316_235959_daily_001.xml.zip
# 6       purchaseProtocol_Chukotskii_AO_20180320_000000_20180320_235959_daily_001.xml.zip
# 7       purchaseProtocol_Chukotskii_AO_20180321_000000_20180321_235959_daily_001.xml.zip
# 8       purchaseProtocol_Chukotskii_AO_20180321_000000_20180321_235959_daily_001.xml.zip
# 9       purchaseProtocol_Chukotskii_AO_20180322_000000_20180322_235959_daily_001.xml.zip
# 10      purchaseProtocol_Chukotskii_AO_20180322_000000_20180322_235959_daily_001.xml.zip
# 11      purchaseProtocol_Chukotskii_AO_20180322_000000_20180322_235959_daily_001.xml.zip
# 12      purchaseProtocol_Chukotskii_AO_20180323_000000_20180323_235959_daily_001.xml.zip
# 13      purchaseProtocol_Chukotskii_AO_20180329_000000_20180329_235959_daily_001.xml.zip
# 14      purchaseProtocol_Chukotskii_AO_20180329_000000_20180329_235959_daily_001.xml.zip
# 15      purchaseProtocol_Chukotskii_AO_20180329_000000_20180329_235959_daily_001.xml.zip
# 16      purchaseProtocol_Chukotskii_AO_20180330_000000_20180330_235959_daily_001.xml.zip
# 17      purchaseProtocol_Chukotskii_AO_20180402_000000_20180402_235959_daily_001.xml.zip
# 18      purchaseProtocol_Chukotskii_AO_20180402_000000_20180402_235959_daily_001.xml.zip
# 19      purchaseProtocol_Chukotskii_AO_20180404_000000_20180404_235959_daily_001.xml.zip
# 20      purchaseProtocol_Chukotskii_AO_20180404_000000_20180404_235959_daily_001.xml.zip
# 21      purchaseProtocol_Chukotskii_AO_20180405_000000_20180405_235959_daily_001.xml.zip
# 22      purchaseProtocol_Chukotskii_AO_20180405_000000_20180405_235959_daily_001.xml.zip
# 23      purchaseProtocol_Chukotskii_AO_20180405_000000_20180405_235959_daily_001.xml.zip
# 24      purchaseProtocol_Chukotskii_AO_20180406_000000_20180406_235959_daily_001.xml.zip
# 25      purchaseProtocol_Chukotskii_AO_20180409_000000_20180409_235959_daily_001.xml.zip
# 26      purchaseProtocol_Chukotskii_AO_20180409_000000_20180409_235959_daily_001.xml.zip
# 27      purchaseProtocol_Chukotskii_AO_20180410_000000_20180410_235959_daily_001.xml.zip
# 28      purchaseProtocol_Chukotskii_AO_20180410_000000_20180410_235959_daily_001.xml.zip
# 29      purchaseProtocol_Chukotskii_AO_20180413_000000_20180413_235959_daily_001.xml.zip
# ...                                                                                  ...
# 17627  purchaseProtocol_Tatarstan_Resp_20180822_000000_20180822_235959_daily_001.xml.zip
# 17628  purchaseProtocol_Tatarstan_Resp_20180822_000000_20180822_235959_daily_002.xml.zip
# 17629  purchaseProtocol_Tatarstan_Resp_20180822_000000_20180822_235959_daily_002.xml.zip
# 17630  purchaseProtocol_Tatarstan_Resp_20180822_000000_20180822_235959_daily_002.xml.zip
# 17631  purchaseProtocol_Tatarstan_Resp_20180822_000000_20180822_235959_daily_002.xml.zip
# 17632  purchaseProtocol_Tatarstan_Resp_20180822_000000_20180822_235959_daily_002.xml.zip
# 17633  purchaseProtocol_Tatarstan_Resp_20180822_000000_20180822_235959_daily_002.xml.zip
# 17634  purchaseProtocol_Tatarstan_Resp_20180822_000000_20180822_235959_daily_002.xml.zip
# 17635  purchaseProtocol_Tatarstan_Resp_20180823_000000_20180823_235959_daily_001.xml.zip
# 17636  purchaseProtocol_Tatarstan_Resp_20180823_000000_20180823_235959_daily_001.xml.zip
# 17637  purchaseProtocol_Tatarstan_Resp_20180823_000000_20180823_235959_daily_001.xml.zip
# 17638  purchaseProtocol_Tatarstan_Resp_20180823_000000_20180823_235959_daily_001.xml.zip
# 17639  purchaseProtocol_Tatarstan_Resp_20180823_000000_20180823_235959_daily_002.xml.zip
# 17640  purchaseProtocol_Tatarstan_Resp_20180823_000000_20180823_235959_daily_002.xml.zip
# 17641  purchaseProtocol_Tatarstan_Resp_20180823_000000_20180823_235959_daily_002.xml.zip
# 17642  purchaseProtocol_Tatarstan_Resp_20180823_000000_20180823_235959_daily_002.xml.zip
# 17643  purchaseProtocol_Tatarstan_Resp_20180824_000000_20180824_235959_daily_002.xml.zip
# 17644  purchaseProtocol_Tatarstan_Resp_20180827_000000_20180827_235959_daily_001.xml.zip
# 17645  purchaseProtocol_Tatarstan_Resp_20180827_000000_20180827_235959_daily_001.xml.zip
# 17646  purchaseProtocol_Tatarstan_Resp_20180827_000000_20180827_235959_daily_001.xml.zip
# 17647  purchaseProtocol_Tatarstan_Resp_20180827_000000_20180827_235959_daily_001.xml.zip
# 17648  purchaseProtocol_Tatarstan_Resp_20180827_000000_20180827_235959_daily_001.xml.zip
# 17649  purchaseProtocol_Tatarstan_Resp_20180828_000000_20180828_235959_daily_001.xml.zip
# 17650  purchaseProtocol_Tatarstan_Resp_20180828_000000_20180828_235959_daily_001.xml.zip
# 17651  purchaseProtocol_Tatarstan_Resp_20180828_000000_20180828_235959_daily_002.xml.zip
# 17652  purchaseProtocol_Tatarstan_Resp_20180828_000000_20180828_235959_daily_002.xml.zip
# 17653  purchaseProtocol_Tatarstan_Resp_20180829_000000_20180829_235959_daily_001.xml.zip
# 17654  purchaseProtocol_Tatarstan_Resp_20180829_000000_20180829_235959_daily_002.xml.zip
# 17655  purchaseProtocol_Tatarstan_Resp_20180830_000000_20180830_235959_daily_001.xml.zip
# 17656  purchaseProtocol_Tatarstan_Resp_20180830_000000_20180830_235959_daily_002.xml.zip
#
#                                                                                  xml  \
# 0       purchaseProtocol_Chukotskii_AO_20180111_000000_20180111_235959_daily_001.xml
# 1       purchaseProtocol_Chukotskii_AO_20180112_000000_20180112_235959_daily_002.xml
# 2       purchaseProtocol_Chukotskii_AO_20180115_000000_20180115_235959_daily_003.xml
# 3       purchaseProtocol_Chukotskii_AO_20180118_000000_20180118_235959_daily_002.xml
# 4       purchaseProtocol_Chukotskii_AO_20180305_000000_20180305_235959_daily_002.xml
# 5       purchaseProtocol_Chukotskii_AO_20180316_000000_20180316_235959_daily_005.xml
# 6       purchaseProtocol_Chukotskii_AO_20180320_000000_20180320_235959_daily_001.xml
# 7       purchaseProtocol_Chukotskii_AO_20180321_000000_20180321_235959_daily_001.xml
# 8       purchaseProtocol_Chukotskii_AO_20180321_000000_20180321_235959_daily_003.xml
# 9       purchaseProtocol_Chukotskii_AO_20180322_000000_20180322_235959_daily_001.xml
# 10      purchaseProtocol_Chukotskii_AO_20180322_000000_20180322_235959_daily_002.xml
# 11      purchaseProtocol_Chukotskii_AO_20180322_000000_20180322_235959_daily_003.xml
# 12      purchaseProtocol_Chukotskii_AO_20180323_000000_20180323_235959_daily_002.xml
# 13      purchaseProtocol_Chukotskii_AO_20180329_000000_20180329_235959_daily_003.xml
# 14      purchaseProtocol_Chukotskii_AO_20180329_000000_20180329_235959_daily_005.xml
# 15      purchaseProtocol_Chukotskii_AO_20180329_000000_20180329_235959_daily_006.xml
# 16      purchaseProtocol_Chukotskii_AO_20180330_000000_20180330_235959_daily_003.xml
# 17      purchaseProtocol_Chukotskii_AO_20180402_000000_20180402_235959_daily_001.xml
# 18      purchaseProtocol_Chukotskii_AO_20180402_000000_20180402_235959_daily_005.xml
# 19      purchaseProtocol_Chukotskii_AO_20180404_000000_20180404_235959_daily_003.xml
# 20      purchaseProtocol_Chukotskii_AO_20180404_000000_20180404_235959_daily_006.xml
# 21      purchaseProtocol_Chukotskii_AO_20180405_000000_20180405_235959_daily_002.xml
# 22      purchaseProtocol_Chukotskii_AO_20180405_000000_20180405_235959_daily_003.xml
# 23      purchaseProtocol_Chukotskii_AO_20180405_000000_20180405_235959_daily_006.xml
# 24      purchaseProtocol_Chukotskii_AO_20180406_000000_20180406_235959_daily_004.xml
# 25      purchaseProtocol_Chukotskii_AO_20180409_000000_20180409_235959_daily_004.xml
# 26      purchaseProtocol_Chukotskii_AO_20180409_000000_20180409_235959_daily_006.xml
# 27      purchaseProtocol_Chukotskii_AO_20180410_000000_20180410_235959_daily_001.xml
# 28      purchaseProtocol_Chukotskii_AO_20180410_000000_20180410_235959_daily_002.xml
# 29      purchaseProtocol_Chukotskii_AO_20180413_000000_20180413_235959_daily_006.xml
# ...                                                                              ...
# 17627  purchaseProtocol_Tatarstan_Resp_20180822_000000_20180822_235959_daily_001.xml
# 17628  purchaseProtocol_Tatarstan_Resp_20180822_000000_20180822_235959_daily_006.xml
# 17629  purchaseProtocol_Tatarstan_Resp_20180822_000000_20180822_235959_daily_025.xml
# 17630  purchaseProtocol_Tatarstan_Resp_20180822_000000_20180822_235959_daily_026.xml
# 17631  purchaseProtocol_Tatarstan_Resp_20180822_000000_20180822_235959_daily_027.xml
# 17632  purchaseProtocol_Tatarstan_Resp_20180822_000000_20180822_235959_daily_028.xml
# 17633  purchaseProtocol_Tatarstan_Resp_20180822_000000_20180822_235959_daily_029.xml
# 17634  purchaseProtocol_Tatarstan_Resp_20180822_000000_20180822_235959_daily_030.xml
# 17635  purchaseProtocol_Tatarstan_Resp_20180823_000000_20180823_235959_daily_001.xml
# 17636  purchaseProtocol_Tatarstan_Resp_20180823_000000_20180823_235959_daily_002.xml
# 17637  purchaseProtocol_Tatarstan_Resp_20180823_000000_20180823_235959_daily_004.xml
# 17638  purchaseProtocol_Tatarstan_Resp_20180823_000000_20180823_235959_daily_015.xml
# 17639  purchaseProtocol_Tatarstan_Resp_20180823_000000_20180823_235959_daily_002.xml
# 17640  purchaseProtocol_Tatarstan_Resp_20180823_000000_20180823_235959_daily_013.xml
# 17641  purchaseProtocol_Tatarstan_Resp_20180823_000000_20180823_235959_daily_017.xml
# 17642  purchaseProtocol_Tatarstan_Resp_20180823_000000_20180823_235959_daily_018.xml
# 17643  purchaseProtocol_Tatarstan_Resp_20180824_000000_20180824_235959_daily_017.xml
# 17644  purchaseProtocol_Tatarstan_Resp_20180827_000000_20180827_235959_daily_003.xml
# 17645  purchaseProtocol_Tatarstan_Resp_20180827_000000_20180827_235959_daily_009.xml
# 17646  purchaseProtocol_Tatarstan_Resp_20180827_000000_20180827_235959_daily_010.xml
# 17647  purchaseProtocol_Tatarstan_Resp_20180827_000000_20180827_235959_daily_011.xml
# 17648  purchaseProtocol_Tatarstan_Resp_20180827_000000_20180827_235959_daily_013.xml
# 17649  purchaseProtocol_Tatarstan_Resp_20180828_000000_20180828_235959_daily_006.xml
# 17650  purchaseProtocol_Tatarstan_Resp_20180828_000000_20180828_235959_daily_015.xml
# 17651  purchaseProtocol_Tatarstan_Resp_20180828_000000_20180828_235959_daily_001.xml
# 17652  purchaseProtocol_Tatarstan_Resp_20180828_000000_20180828_235959_daily_002.xml
# 17653  purchaseProtocol_Tatarstan_Resp_20180829_000000_20180829_235959_daily_011.xml
# 17654  purchaseProtocol_Tatarstan_Resp_20180829_000000_20180829_235959_daily_001.xml
# 17655  purchaseProtocol_Tatarstan_Resp_20180830_000000_20180830_235959_daily_003.xml
# 17656  purchaseProtocol_Tatarstan_Resp_20180830_000000_20180830_235959_daily_001.xml
#
#                region
# 0       Chukotskii_AO
# 1       Chukotskii_AO
# 2       Chukotskii_AO
# 3       Chukotskii_AO
# 4       Chukotskii_AO
# 5       Chukotskii_AO
# 6       Chukotskii_AO
# 7       Chukotskii_AO
# 8       Chukotskii_AO
# 9       Chukotskii_AO
# 10      Chukotskii_AO
# 11      Chukotskii_AO
# 12      Chukotskii_AO
# 13      Chukotskii_AO
# 14      Chukotskii_AO
# 15      Chukotskii_AO
# 16      Chukotskii_AO
# 17      Chukotskii_AO
# 18      Chukotskii_AO
# 19      Chukotskii_AO
# 20      Chukotskii_AO
# 21      Chukotskii_AO
# 22      Chukotskii_AO
# 23      Chukotskii_AO
# 24      Chukotskii_AO
# 25      Chukotskii_AO
# 26      Chukotskii_AO
# 27      Chukotskii_AO
# 28      Chukotskii_AO
# 29      Chukotskii_AO
# ...               ...
# 17627  Tatarstan_Resp
# 17628  Tatarstan_Resp
# 17629  Tatarstan_Resp
# 17630  Tatarstan_Resp
# 17631  Tatarstan_Resp
# 17632  Tatarstan_Resp
# 17633  Tatarstan_Resp
# 17634  Tatarstan_Resp
# 17635  Tatarstan_Resp
# 17636  Tatarstan_Resp
# 17637  Tatarstan_Resp
# 17638  Tatarstan_Resp
# 17639  Tatarstan_Resp
# 17640  Tatarstan_Resp
# 17641  Tatarstan_Resp
# 17642  Tatarstan_Resp
# 17643  Tatarstan_Resp
# 17644  Tatarstan_Resp
# 17645  Tatarstan_Resp
# 17646  Tatarstan_Resp
# 17647  Tatarstan_Resp
# 17648  Tatarstan_Resp
# 17649  Tatarstan_Resp
# 17650  Tatarstan_Resp
# 17651  Tatarstan_Resp
# 17652  Tatarstan_Resp
# 17653  Tatarstan_Resp
# 17654  Tatarstan_Resp
# 17655  Tatarstan_Resp
# 17656  Tatarstan_Resp
#
# [17657 rows x 8 columns]

# %% [markdown]
# ### Создать таблицу
# create table ZAKUPKI_PROTOKOLVK
# (
#   nnumber   VARCHAR2(100),
#   mcode     VARCHAR2(4),
#   mname     VARCHAR2(1000),
#   nsupplier VARCHAR2(1000),
#   ncount    number(4),
#   zip       VARCHAR2(255),
#   nxml      VARCHAR2(255),
#   nregion   VARCHAR2(255)
# )
# tablespace USERS
#   pctfree 10
#   initrans 1
#   maxtrans 255
#   storage
#   (
#     initial 64K
#     next 1M
#     minextents 1
#     maxextents unlimited
#   );

# %%
contracts['okpd2']=contracts['okpd2'].apply('; '.join)
contracts['okpd']=contracts['okpd'].apply('; '.join)
contracts['okdp']=contracts['okdp'].apply('; '.join)

# %%
load_df_to_ora(contracts)
# Out:
#  Обработано строк: 100
#  Обработано строк: 200
#  Обработано строк: 300
#  Обработано строк: 400
#  Обработано строк: 500
#  Обработано строк: 600
#  Обработано строк: 700
#  Обработано строк: 800
#  Обработано строк: 900
#  Обработано строк: 1000
#  Обработано строк: 1100
#  Обработано строк: 1200
#  Обработано строк: 1300
#  Обработано строк: 1400
#  Обработано строк: 1500
#  Обработано строк: 1600
#  Обработано строк: 1700
#  Обработано строк: 1800
#  Обработано строк: 1900
#  Обработано строк: 2000
#  Обработано строк: 2100
#  Обработано строк: 2200
#  Обработано строк: 2300
#  Обработано строк: 2400
#  Обработано строк: 2500
#  Обработано строк: 2600
#  Обработано строк: 2700
#  Обработано строк: 2800
#  Обработано строк: 2900
#  Обработано строк: 3000
#  Обработано строк: 3100
#  Обработано строк: 3200
#  Обработано строк: 3300
#  Обработано строк: 3400
#  Обработано строк: 3500
#  Обработано строк: 3600
#  Обработано строк: 3700
#  Обработано строк: 3800
#  Обработано строк: 3900
#  Обработано строк: 4000
#  Обработано строк: 4100
#  Обработано строк: 4200
#  Обработано строк: 4300
#  Обработано строк: 4400
#  Обработано строк: 4500
#  Обработано строк: 4600
#  Обработано строк: 4700
#  Обработано строк: 4800
#  Обработано строк: 4900
#  Обработано строк: 5000
#  Обработано строк: 5100
#  Обработано строк: 5200
#  Обработано строк: 5300
#  Обработано строк: 5400
#  Обработано строк: 5500
#  Обработано строк: 5600
#  Обработано строк: 5700
#  Обработано строк: 5800
#  Обработано строк: 5900
#  Обработано строк: 6000
#  Обработано строк: 6100
#  Обработано строк: 6200
#  Обработано строк: 6300
#  Обработано строк: 6400
#  Обработано строк: 6500
#  Обработано строк: 6600
#  Обработано строк: 6700
#  Обработано строк: 6800
#  Обработано строк: 6900
#  Обработано строк: 7000
#  Обработано строк: 7100
#  Обработано строк: 7200
#  Обработано строк: 7300
#  Обработано строк: 7400
#  Обработано строк: 7500
#  Обработано строк: 7600
#  Обработано строк: 7700
#  Обработано строк: 7800
#  Обработано строк: 7900
#  Обработано строк: 8000
#  Обработано строк: 8100
#  Обработано строк: 8200
#  Обработано строк: 8300
#  Обработано строк: 8400
#  Обработано строк: 8500
#  Обработано строк: 8600
#  Обработано строк: 8700
#  Обработано строк: 8800
#  Обработано строк: 8900
#  Обработано строк: 9000
#  Обработано строк: 9100
#  Обработано строк: 9200
#  Обработано строк: 9300
#  Обработано строк: 9400
#  Обработано строк: 9500
#  Обработано строк: 9600
#  Обработано строк: 9700
#  Обработано строк: 9800
#  Обработано строк: 9900
#  Обработано строк: 10000
#  Обработано строк: 10100
#  Обработано строк: 10200
#  Обработано строк: 10300
#  Обработано строк: 10400
#  Обработано строк: 10500
#  Обработано строк: 10600
#  Обработано строк: 10700
#  Обработано строк: 10800
#  Обработано строк: 10900
#  Обработано строк: 11000
#  Обработано строк: 11100
#  Обработано строк: 11200
#  Обработано строк: 11300
#  Обработано строк: 11400
#  Обработано строк: 11500
#  Обработано строк: 11600
#  Обработано строк: 11700
#  Обработано строк: 11800
#  Обработано строк: 11900
#  Обработано строк: 12000
#  Обработано строк: 12100
#  Обработано строк: 12200
#  Обработано строк: 12300
#  Обработано строк: 12400
#  Обработано строк: 12500
#  Обработано строк: 12600
#  Обработано строк: 12700
#  Обработано строк: 12800
#  Обработано строк: 12900
#  Обработано строк: 13000
#  Обработано строк: 13100
#  Обработано строк: 13200
#  Обработано строк: 13300
#  Обработано строк: 13400
#  Обработано строк: 13500
#  Обработано строк: 13600
#  Обработано строк: 13700
#  Обработано строк: 13800
#  Обработано строк: 13900
#  Обработано строк: 14000
#  Обработано строк: 14100
#  Обработано строк: 14200
#  Обработано строк: 14300
#  Обработано строк: 14400
#  Обработано строк: 14500
#  Обработано строк: 14600
#  Обработано строк: 14700
#  Обработано строк: 14800
#  Обработано строк: 14900
#  Обработано строк: 15000
#  Обработано строк: 15100
#  Обработано строк: 15200
#  Обработано строк: 15300
#  Обработано строк: 15400
#  Обработано строк: 15500
#  Обработано строк: 15600
#  Обработано строк: 15700
#  Обработано строк: 15800
#  Обработано строк: 15900
#  Обработано строк: 16000
#  Обработано строк: 16100
#  Обработано строк: 16200
#  Обработано строк: 16300
#  Обработано строк: 16400
#  Обработано строк: 16500
#  Обработано строк: 16600
#  Обработано строк: 16700
#  Обработано строк: 16800
#  Обработано строк: 16900
#  Обработано строк: 17000
#  Обработано строк: 17100
#  Обработано строк: 17200
#  Обработано строк: 17300
#  Обработано строк: 17400
#  Обработано строк: 17500
#  Обработано строк: 17600
